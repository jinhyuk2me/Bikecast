# %%
import mysql.connector
import pandas as pd

class RentalDBManager :

    def __init__(self, host, port, user, password, database):
        self.host = host
        self.port = port
        self.user = user
        self.password = password
        self.database = database
        self.db = mysql.connector.connect(
            host=host,
            port=port,
            user=user,
            password=password,
            database=database
        )
        self.cursor = self.db.cursor(buffered=True)
        print("DB connected")

    def close(self):
        if self.cursor:
            self.cursor.close()
        if self.db:
            self.db.close()
        print("DB disconnected")

    def insert(self, rental_datetime, return_datetime, rental_station_id, return_station_id, distance, birth_year):

        sql = """
        INSERT INTO rental (
            rental_datetime, return_datetime,
            rental_station_id, return_station_id,
            distance, birth_year
        ) VALUES (%s, %s, %s, %s, %s, %s)
        """
        self.cursor.execute(sql, (rental_datetime, return_datetime, rental_station_id, return_station_id, distance, birth_year))
        self.db.commit()
        print("INSERTED")
        return True

    def select_all(self, table):
        sql = f"SELECT * FROM {table}"
        self.cursor.execute(sql)
        result = self.cursor.fetchall()
        columns = [col[0] for col in self.cursor.description]
        df = pd.DataFrame(result, columns=columns).reset_index(drop=True)
        return df

    def execute(self, sql):
        self.cursor.execute(sql)
        self.db.commit()
        print("------------------------------------------")
        print("EXECUTED")
        if self.cursor.description is not None:
            result = self.cursor.fetchall()
            print(result)
        return True

dbm = RentalDBManager(
    host="jinhyuk2db.c94oygiiukcg.ap-northeast-2.rds.amazonaws.com",
    port= 3306,
    user="root",
    password="jinhyuk2dacibul",
    database="project1"
)
# Out:
# DB connected

# %%
import pandas as pd
import glob
import os

# 경로 지정
folder_path = '/content/drive/MyDrive/EDA Project/대여이력/'
chunksize = 100000
all_chunks = []

# 모든 CSV 파일 경로 가져오기
file_list = glob.glob(os.path.join(folder_path, '*.csv'))

# 파일별로 chunk 단위로 읽어서 리스트에 추가
for file in file_list:
    print(f"📂 {os.path.basename(file)} 읽는 중...")
    for chunk in pd.read_csv(file, chunksize=chunksize, encoding='cp949', low_memory=False):
        all_chunks.append(chunk)

# 하나의 DataFrame으로 합치기
df12 = pd.concat(all_chunks, ignore_index=True)
print("✅ 모든 파일 병합 완료:", df12.shape)
# Out:
# 📂 서울특별시 공공자전거 대여이력 정보_2404.csv 읽는 중...
# 📂 서울특별시 공공자전거 대여이력 정보_2403.csv 읽는 중...
# 📂 서울특별시 공공자전거 대여이력 정보_2405.csv 읽는 중...
# 📂 서울특별시 공공자전거 대여이력 정보_2409.csv 읽는 중...
# 📂 서울특별시 공공자전거 대여이력 정보_2412.csv 읽는 중...
# 📂 서울특별시 공공자전거 대여이력 정보_2411.csv 읽는 중...
# 📂 서울특별시 공공자전거 대여이력 정보_2410.csv 읽는 중...
# 📂 서울특별시 공공자전거 대여이력 정보_2402.csv 읽는 중...
# 📂 서울특별시 공공자전거 대여이력 정보_2408.csv 읽는 중...
# 📂 서울특별시 공공자전거 대여이력 정보_2407.csv 읽는 중...
# 📂 서울특별시 공공자전거 대여이력 정보_2406.csv 읽는 중...
# 📂 서울특별시 공공자전거 대여이력 정보_2401.csv 읽는 중...
# ✅ 모든 파일 병합 완료: (44543263, 17)

# %%
df = df12[['대여일시', '반납일시', '대여대여소ID', '반납대여소ID', '이용거리(M)', '생년']]
df['생년'] = df['생년'].replace('\\N', pd.NA)
df = df.where(pd.notnull(df), None)
# Out:
# <ipython-input-6-79d9ac35e4df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['생년'] = df['생년'].replace('\\N', pd.NA)

# %%
from tqdm import tqdm
from datetime import datetime

# 전처리: NaN → None
df = df.where(pd.notnull(df), None)

# 날짜 변환
df['대여일시'] = pd.to_datetime(df['대여일시'], errors='coerce')
df['반납일시'] = pd.to_datetime(df['반납일시'], errors='coerce')

# 리스트로 변환 (진행률 표시)
values = []
for i, row in tqdm(df.iterrows(), total=len(df), desc="데이터 변환 중"):
    rental_time = row['대여일시'].to_pydatetime() if isinstance(row['대여일시'], pd.Timestamp) else None
    return_time = row['반납일시'].to_pydatetime() if isinstance(row['반납일시'], pd.Timestamp) else None

    values.append((
        rental_time,
        return_time,
        row['대여대여소ID'],
        row['반납대여소ID'],
        float(row['이용거리(M)']) if row['이용거리(M)'] is not None else None,
        int(row['생년']) if row['생년'] is not None else None,
    ))

    if i < 5:
        print(values[-1])
# Out:
# 데이터 변환 중:   0%|          | 2767/44543263 [02:24<370:59:03, 33.35it/s]
# (datetime.datetime(2024, 4, 1, 0, 0, 2), datetime.datetime(2024, 4, 1, 0, 0, 11), 'ST-2827', 'ST-2827', 0.0, 2004)
# (datetime.datetime(2024, 4, 1, 0, 0, 38), datetime.datetime(2024, 4, 1, 0, 0, 48), 'ST-492', 'ST-492', 0.0, 2003)
# (datetime.datetime(2024, 4, 1, 0, 0, 38), datetime.datetime(2024, 4, 1, 0, 0, 55), 'ST-1105', 'ST-1105', 0.0, 2001)
# (datetime.datetime(2024, 4, 1, 0, 1, 44), datetime.datetime(2024, 4, 1, 0, 1, 52), 'ST-112', 'ST-112', 0.0, 1998)
# (datetime.datetime(2024, 4, 1, 0, 0, 5), datetime.datetime(2024, 4, 1, 0, 1, 56), 'ST-1435', 'ST-2513', 260.0, 1999)
# 데이터 변환 중: 100%|██████████| 44543263/44543263 [57:04<00:00, 13005.86it/s]

# %%
sql = """
    INSERT INTO rental (
        rental_datetime, return_datetime,
        rental_station_id, return_station_id, distance,
        birth_year
    ) VALUES (%s, %s, %s, %s, %s, %s)
"""

batch_size = 10000

for i in range(0, len(values), batch_size):
    batch = values[i:i+batch_size]
    dbm.cursor.executemany(sql, batch)
    dbm.db.commit()
    print(f"✅ [{i} ~ {i+len(batch)}] INSERT 완료")
# Out:
# ✅ [0 ~ 10000] INSERT 완료
# ✅ [10000 ~ 20000] INSERT 완료
# ✅ [20000 ~ 30000] INSERT 완료
# ✅ [30000 ~ 40000] INSERT 완료
# ✅ [40000 ~ 50000] INSERT 완료
# ✅ [50000 ~ 60000] INSERT 완료
# ✅ [60000 ~ 70000] INSERT 완료
# ✅ [70000 ~ 80000] INSERT 완료
# ✅ [80000 ~ 90000] INSERT 완료
# ✅ [90000 ~ 100000] INSERT 완료
# ✅ [100000 ~ 110000] INSERT 완료
# ✅ [110000 ~ 120000] INSERT 완료
# ✅ [120000 ~ 130000] INSERT 완료
# ✅ [130000 ~ 140000] INSERT 완료
# ✅ [140000 ~ 150000] INSERT 완료
# ✅ [150000 ~ 160000] INSERT 완료
# ✅ [160000 ~ 170000] INSERT 완료
# ✅ [170000 ~ 180000] INSERT 완료
# ✅ [180000 ~ 190000] INSERT 완료
# ✅ [190000 ~ 200000] INSERT 완료
# ✅ [200000 ~ 210000] INSERT 완료
# ✅ [210000 ~ 220000] INSERT 완료
# ✅ [220000 ~ 230000] INSERT 완료
# ✅ [230000 ~ 240000] INSERT 완료
# ✅ [240000 ~ 250000] INSERT 완료
# ✅ [250000 ~ 260000] INSERT 완료
# ✅ [260000 ~ 270000] INSERT 완료
# ✅ [270000 ~ 280000] INSERT 완료
# ✅ [280000 ~ 290000] INSERT 완료
# ✅ [290000 ~ 300000] INSERT 완료
# ✅ [300000 ~ 310000] INSERT 완료
# ✅ [310000 ~ 320000] INSERT 완료
# ✅ [320000 ~ 330000] INSERT 완료
# ✅ [330000 ~ 340000] INSERT 완료
# ✅ [340000 ~ 350000] INSERT 완료
# ✅ [350000 ~ 360000] INSERT 완료
# ✅ [360000 ~ 370000] INSERT 완료
# ✅ [370000 ~ 380000] INSERT 완료
# ✅ [380000 ~ 390000] INSERT 완료
# ✅ [390000 ~ 400000] INSERT 완료
# ✅ [400000 ~ 410000] INSERT 완료
# ✅ [410000 ~ 420000] INSERT 완료
# ✅ [420000 ~ 430000] INSERT 완료
# ✅ [430000 ~ 440000] INSERT 완료
# ✅ [440000 ~ 450000] INSERT 완료
# ✅ [450000 ~ 460000] INSERT 완료
# ✅ [460000 ~ 470000] INSERT 완료
# ✅ [470000 ~ 480000] INSERT 완료
# ✅ [480000 ~ 490000] INSERT 완료
# ✅ [490000 ~ 500000] INSERT 완료
# ✅ [500000 ~ 510000] INSERT 완료
# ✅ [510000 ~ 520000] INSERT 완료
# ✅ [520000 ~ 530000] INSERT 완료
# ✅ [530000 ~ 540000] INSERT 완료
# ✅ [540000 ~ 550000] INSERT 완료
# ✅ [550000 ~ 560000] INSERT 완료
# ✅ [560000 ~ 570000] INSERT 완료
# ✅ [570000 ~ 580000] INSERT 완료
# ✅ [580000 ~ 590000] INSERT 완료
# ✅ [590000 ~ 600000] INSERT 완료
# ✅ [600000 ~ 610000] INSERT 완료
# ✅ [610000 ~ 620000] INSERT 완료
# ✅ [620000 ~ 630000] INSERT 완료
# ✅ [630000 ~ 640000] INSERT 완료
# ✅ [640000 ~ 650000] INSERT 완료
# ✅ [650000 ~ 660000] INSERT 완료
# ✅ [660000 ~ 670000] INSERT 완료
# ✅ [670000 ~ 680000] INSERT 완료
# ✅ [680000 ~ 690000] INSERT 완료
# ✅ [690000 ~ 700000] INSERT 완료
# ✅ [700000 ~ 710000] INSERT 완료
# ✅ [710000 ~ 720000] INSERT 완료
# ✅ [720000 ~ 730000] INSERT 완료
# ✅ [730000 ~ 740000] INSERT 완료
# ✅ [740000 ~ 750000] INSERT 완료
# ✅ [750000 ~ 760000] INSERT 완료
# ✅ [760000 ~ 770000] INSERT 완료
# ✅ [770000 ~ 780000] INSERT 완료
# ✅ [780000 ~ 790000] INSERT 완료
# ✅ [790000 ~ 800000] INSERT 완료
# ✅ [800000 ~ 810000] INSERT 완료
# ✅ [810000 ~ 820000] INSERT 완료
# ✅ [820000 ~ 830000] INSERT 완료
# ✅ [830000 ~ 840000] INSERT 완료
# ✅ [840000 ~ 850000] INSERT 완료
# ✅ [850000 ~ 860000] INSERT 완료
# ✅ [860000 ~ 870000] INSERT 완료
# ✅ [870000 ~ 880000] INSERT 완료
# ✅ [880000 ~ 890000] INSERT 완료
# ✅ [890000 ~ 900000] INSERT 완료
# ✅ [900000 ~ 910000] INSERT 완료
# ✅ [910000 ~ 920000] INSERT 완료
# ✅ [920000 ~ 930000] INSERT 완료
# ✅ [930000 ~ 940000] INSERT 완료
# ✅ [940000 ~ 950000] INSERT 완료
# ✅ [950000 ~ 960000] INSERT 완료
# ✅ [960000 ~ 970000] INSERT 완료
# ✅ [970000 ~ 980000] INSERT 완료
# ✅ [980000 ~ 990000] INSERT 완료
# ✅ [990000 ~ 1000000] INSERT 완료
# ✅ [1000000 ~ 1010000] INSERT 완료
# ✅ [1010000 ~ 1020000] INSERT 완료
# ✅ [1020000 ~ 1030000] INSERT 완료
# ✅ [1030000 ~ 1040000] INSERT 완료
# ✅ [1040000 ~ 1050000] INSERT 완료
# ✅ [1050000 ~ 1060000] INSERT 완료
# ✅ [1060000 ~ 1070000] INSERT 완료
# ✅ [1070000 ~ 1080000] INSERT 완료
# ✅ [1080000 ~ 1090000] INSERT 완료
# ✅ [1090000 ~ 1100000] INSERT 완료
# ✅ [1100000 ~ 1110000] INSERT 완료
# ✅ [1110000 ~ 1120000] INSERT 완료
# ✅ [1120000 ~ 1130000] INSERT 완료
# ✅ [1130000 ~ 1140000] INSERT 완료
# ✅ [1140000 ~ 1150000] INSERT 완료
# ✅ [1150000 ~ 1160000] INSERT 완료
# ✅ [1160000 ~ 1170000] INSERT 완료
# ✅ [1170000 ~ 1180000] INSERT 완료
# ✅ [1180000 ~ 1190000] INSERT 완료
# ✅ [1190000 ~ 1200000] INSERT 완료
# ✅ [1200000 ~ 1210000] INSERT 완료
# ✅ [1210000 ~ 1220000] INSERT 완료
# ✅ [1220000 ~ 1230000] INSERT 완료
# ✅ [1230000 ~ 1240000] INSERT 완료
# ✅ [1240000 ~ 1250000] INSERT 완료
# ✅ [1250000 ~ 1260000] INSERT 완료
# ✅ [1260000 ~ 1270000] INSERT 완료
# ✅ [1270000 ~ 1280000] INSERT 완료
# ✅ [1280000 ~ 1290000] INSERT 완료
# ✅ [1290000 ~ 1300000] INSERT 완료
# ✅ [1300000 ~ 1310000] INSERT 완료
# ✅ [1310000 ~ 1320000] INSERT 완료
# ✅ [1320000 ~ 1330000] INSERT 완료
# ✅ [1330000 ~ 1340000] INSERT 완료
# ✅ [1340000 ~ 1350000] INSERT 완료
# ✅ [1350000 ~ 1360000] INSERT 완료
# ✅ [1360000 ~ 1370000] INSERT 완료
# ✅ [1370000 ~ 1380000] INSERT 완료
# ✅ [1380000 ~ 1390000] INSERT 완료
# ✅ [1390000 ~ 1400000] INSERT 완료
# ✅ [1400000 ~ 1410000] INSERT 완료
# ✅ [1410000 ~ 1420000] INSERT 완료
# ✅ [1420000 ~ 1430000] INSERT 완료
# ✅ [1430000 ~ 1440000] INSERT 완료
# ✅ [1440000 ~ 1450000] INSERT 완료
# ✅ [1450000 ~ 1460000] INSERT 완료
# ✅ [1460000 ~ 1470000] INSERT 완료
# ✅ [1470000 ~ 1480000] INSERT 완료
# ✅ [1480000 ~ 1490000] INSERT 완료
# ✅ [1490000 ~ 1500000] INSERT 완료
# ✅ [1500000 ~ 1510000] INSERT 완료
# ✅ [1510000 ~ 1520000] INSERT 완료
# ✅ [1520000 ~ 1530000] INSERT 완료
# ✅ [1530000 ~ 1540000] INSERT 완료
# ✅ [1540000 ~ 1550000] INSERT 완료
# ✅ [1550000 ~ 1560000] INSERT 완료
# ✅ [1560000 ~ 1570000] INSERT 완료
# ✅ [1570000 ~ 1580000] INSERT 완료
# ✅ [1580000 ~ 1590000] INSERT 완료
# ✅ [1590000 ~ 1600000] INSERT 완료
# ✅ [1600000 ~ 1610000] INSERT 완료
# ✅ [1610000 ~ 1620000] INSERT 완료
# ✅ [1620000 ~ 1630000] INSERT 완료
# ✅ [1630000 ~ 1640000] INSERT 완료
# ✅ [1640000 ~ 1650000] INSERT 완료
# ✅ [1650000 ~ 1660000] INSERT 완료
# ✅ [1660000 ~ 1670000] INSERT 완료
# ✅ [1670000 ~ 1680000] INSERT 완료
# ✅ [1680000 ~ 1690000] INSERT 완료
# ✅ [1690000 ~ 1700000] INSERT 완료
# ✅ [1700000 ~ 1710000] INSERT 완료
# ✅ [1710000 ~ 1720000] INSERT 완료
# ✅ [1720000 ~ 1730000] INSERT 완료
# ✅ [1730000 ~ 1740000] INSERT 완료
# ✅ [1740000 ~ 1750000] INSERT 완료
# ✅ [1750000 ~ 1760000] INSERT 완료
# ✅ [1760000 ~ 1770000] INSERT 완료
# ✅ [1770000 ~ 1780000] INSERT 완료
# ✅ [1780000 ~ 1790000] INSERT 완료
# ✅ [1790000 ~ 1800000] INSERT 완료
# ✅ [1800000 ~ 1810000] INSERT 완료
# ✅ [1810000 ~ 1820000] INSERT 완료
# ✅ [1820000 ~ 1830000] INSERT 완료
# ✅ [1830000 ~ 1840000] INSERT 완료
# ✅ [1840000 ~ 1850000] INSERT 완료
# ✅ [1850000 ~ 1860000] INSERT 완료
# ✅ [1860000 ~ 1870000] INSERT 완료
# ✅ [1870000 ~ 1880000] INSERT 완료
# ✅ [1880000 ~ 1890000] INSERT 완료
# ✅ [1890000 ~ 1900000] INSERT 완료
# ✅ [1900000 ~ 1910000] INSERT 완료
# ✅ [1910000 ~ 1920000] INSERT 완료
# ✅ [1920000 ~ 1930000] INSERT 완료
# ✅ [1930000 ~ 1940000] INSERT 완료
# ✅ [1940000 ~ 1950000] INSERT 완료
# ✅ [1950000 ~ 1960000] INSERT 완료
# ✅ [1960000 ~ 1970000] INSERT 완료
# ✅ [1970000 ~ 1980000] INSERT 완료
# ✅ [1980000 ~ 1990000] INSERT 완료
# ✅ [1990000 ~ 2000000] INSERT 완료
# ✅ [2000000 ~ 2010000] INSERT 완료
# ✅ [2010000 ~ 2020000] INSERT 완료
# ✅ [2020000 ~ 2030000] INSERT 완료
# ✅ [2030000 ~ 2040000] INSERT 완료
# ✅ [2040000 ~ 2050000] INSERT 완료
# ✅ [2050000 ~ 2060000] INSERT 완료
# ✅ [2060000 ~ 2070000] INSERT 완료
# ✅ [2070000 ~ 2080000] INSERT 완료
# ✅ [2080000 ~ 2090000] INSERT 완료
# ✅ [2090000 ~ 2100000] INSERT 완료
# ✅ [2100000 ~ 2110000] INSERT 완료
# ✅ [2110000 ~ 2120000] INSERT 완료
# ✅ [2120000 ~ 2130000] INSERT 완료
# ✅ [2130000 ~ 2140000] INSERT 완료
# ✅ [2140000 ~ 2150000] INSERT 완료
# ✅ [2150000 ~ 2160000] INSERT 완료
# ✅ [2160000 ~ 2170000] INSERT 완료
# ✅ [2170000 ~ 2180000] INSERT 완료
# ✅ [2180000 ~ 2190000] INSERT 완료
# ✅ [2190000 ~ 2200000] INSERT 완료
# ✅ [2200000 ~ 2210000] INSERT 완료
# ✅ [2210000 ~ 2220000] INSERT 완료
# ✅ [2220000 ~ 2230000] INSERT 완료
# ✅ [2230000 ~ 2240000] INSERT 완료
# ✅ [2240000 ~ 2250000] INSERT 완료
# ✅ [2250000 ~ 2260000] INSERT 완료
# ✅ [2260000 ~ 2270000] INSERT 완료
# ✅ [2270000 ~ 2280000] INSERT 완료
# ✅ [2280000 ~ 2290000] INSERT 완료
# ✅ [2290000 ~ 2300000] INSERT 완료
# ✅ [2300000 ~ 2310000] INSERT 완료
# ✅ [2310000 ~ 2320000] INSERT 완료
# ✅ [2320000 ~ 2330000] INSERT 완료
# ✅ [2330000 ~ 2340000] INSERT 완료
# ✅ [2340000 ~ 2350000] INSERT 완료
# ✅ [2350000 ~ 2360000] INSERT 완료
# ✅ [2360000 ~ 2370000] INSERT 완료
# ✅ [2370000 ~ 2380000] INSERT 완료
# ✅ [2380000 ~ 2390000] INSERT 완료
# ✅ [2390000 ~ 2400000] INSERT 완료
# ✅ [2400000 ~ 2410000] INSERT 완료
# ✅ [2410000 ~ 2420000] INSERT 완료
# ✅ [2420000 ~ 2430000] INSERT 완료
# ✅ [2430000 ~ 2440000] INSERT 완료
# ✅ [2440000 ~ 2450000] INSERT 완료
# ✅ [2450000 ~ 2460000] INSERT 완료
# ✅ [2460000 ~ 2470000] INSERT 완료
# ✅ [2470000 ~ 2480000] INSERT 완료
# ✅ [2480000 ~ 2490000] INSERT 완료
# ✅ [2490000 ~ 2500000] INSERT 완료
# ✅ [2500000 ~ 2510000] INSERT 완료
# ✅ [2510000 ~ 2520000] INSERT 완료
# ✅ [2520000 ~ 2530000] INSERT 완료
# ✅ [2530000 ~ 2540000] INSERT 완료
# ✅ [2540000 ~ 2550000] INSERT 완료
# ✅ [2550000 ~ 2560000] INSERT 완료
# ✅ [2560000 ~ 2570000] INSERT 완료
# ✅ [2570000 ~ 2580000] INSERT 완료
# ✅ [2580000 ~ 2590000] INSERT 완료
# ✅ [2590000 ~ 2600000] INSERT 완료
# ✅ [2600000 ~ 2610000] INSERT 완료
# ✅ [2610000 ~ 2620000] INSERT 완료
# ✅ [2620000 ~ 2630000] INSERT 완료
# ✅ [2630000 ~ 2640000] INSERT 완료
# ✅ [2640000 ~ 2650000] INSERT 완료
# ✅ [2650000 ~ 2660000] INSERT 완료
# ✅ [2660000 ~ 2670000] INSERT 완료
# ✅ [2670000 ~ 2680000] INSERT 완료
# ✅ [2680000 ~ 2690000] INSERT 완료
# ✅ [2690000 ~ 2700000] INSERT 완료
# ✅ [2700000 ~ 2710000] INSERT 완료
# ✅ [2710000 ~ 2720000] INSERT 완료
# ✅ [2720000 ~ 2730000] INSERT 완료
# ✅ [2730000 ~ 2740000] INSERT 완료
# ✅ [2740000 ~ 2750000] INSERT 완료
# ✅ [2750000 ~ 2760000] INSERT 완료
# ✅ [2760000 ~ 2770000] INSERT 완료
# ✅ [2770000 ~ 2780000] INSERT 완료
# ✅ [2780000 ~ 2790000] INSERT 완료
# ✅ [2790000 ~ 2800000] INSERT 완료
# ✅ [2800000 ~ 2810000] INSERT 완료
# ✅ [2810000 ~ 2820000] INSERT 완료
# ✅ [2820000 ~ 2830000] INSERT 완료
# ✅ [2830000 ~ 2840000] INSERT 완료
# ✅ [2840000 ~ 2850000] INSERT 완료
# ✅ [2850000 ~ 2860000] INSERT 완료
# ✅ [2860000 ~ 2870000] INSERT 완료
# ✅ [2870000 ~ 2880000] INSERT 완료
# ✅ [2880000 ~ 2890000] INSERT 완료
# ✅ [2890000 ~ 2900000] INSERT 완료
# ✅ [2900000 ~ 2910000] INSERT 완료
# ✅ [2910000 ~ 2920000] INSERT 완료
# ✅ [2920000 ~ 2930000] INSERT 완료
# ✅ [2930000 ~ 2940000] INSERT 완료
# ✅ [2940000 ~ 2950000] INSERT 완료
# ✅ [2950000 ~ 2960000] INSERT 완료
# ✅ [2960000 ~ 2970000] INSERT 완료
# ✅ [2970000 ~ 2980000] INSERT 완료
# ✅ [2980000 ~ 2990000] INSERT 완료
# ✅ [2990000 ~ 3000000] INSERT 완료
# ✅ [3000000 ~ 3010000] INSERT 완료
# ✅ [3010000 ~ 3020000] INSERT 완료
# ✅ [3020000 ~ 3030000] INSERT 완료
# ✅ [3030000 ~ 3040000] INSERT 완료
# ✅ [3040000 ~ 3050000] INSERT 완료
# ✅ [3050000 ~ 3060000] INSERT 완료
# ✅ [3060000 ~ 3070000] INSERT 완료
# ✅ [3070000 ~ 3080000] INSERT 완료
# ✅ [3080000 ~ 3090000] INSERT 완료
# ✅ [3090000 ~ 3100000] INSERT 완료
# ✅ [3100000 ~ 3110000] INSERT 완료
# ✅ [3110000 ~ 3120000] INSERT 완료
# ✅ [3120000 ~ 3130000] INSERT 완료
# ✅ [3130000 ~ 3140000] INSERT 완료
# ✅ [3140000 ~ 3150000] INSERT 완료
# ✅ [3150000 ~ 3160000] INSERT 완료
# ✅ [3160000 ~ 3170000] INSERT 완료
# ✅ [3170000 ~ 3180000] INSERT 완료
# ✅ [3180000 ~ 3190000] INSERT 완료
# ✅ [3190000 ~ 3200000] INSERT 완료
# ✅ [3200000 ~ 3210000] INSERT 완료
# ✅ [3210000 ~ 3220000] INSERT 완료
# ✅ [3220000 ~ 3230000] INSERT 완료
# ✅ [3230000 ~ 3240000] INSERT 완료
# ✅ [3240000 ~ 3250000] INSERT 완료
# ✅ [3250000 ~ 3260000] INSERT 완료
# ✅ [3260000 ~ 3270000] INSERT 완료
# ✅ [3270000 ~ 3280000] INSERT 완료
# ✅ [3280000 ~ 3290000] INSERT 완료
# ✅ [3290000 ~ 3300000] INSERT 완료
# ✅ [3300000 ~ 3310000] INSERT 완료
# ✅ [3310000 ~ 3320000] INSERT 완료
# ✅ [3320000 ~ 3330000] INSERT 완료
# ✅ [3330000 ~ 3340000] INSERT 완료
# ✅ [3340000 ~ 3350000] INSERT 완료
# ✅ [3350000 ~ 3360000] INSERT 완료
# ✅ [3360000 ~ 3370000] INSERT 완료
# ✅ [3370000 ~ 3380000] INSERT 완료
# ✅ [3380000 ~ 3390000] INSERT 완료
# ✅ [3390000 ~ 3400000] INSERT 완료
# ✅ [3400000 ~ 3410000] INSERT 완료
# ✅ [3410000 ~ 3420000] INSERT 완료
# ✅ [3420000 ~ 3430000] INSERT 완료
# ✅ [3430000 ~ 3440000] INSERT 완료
# ✅ [3440000 ~ 3450000] INSERT 완료
# ✅ [3450000 ~ 3460000] INSERT 완료
# ✅ [3460000 ~ 3470000] INSERT 완료
# ✅ [3470000 ~ 3480000] INSERT 완료
# ✅ [3480000 ~ 3490000] INSERT 완료
# ✅ [3490000 ~ 3500000] INSERT 완료
# ✅ [3500000 ~ 3510000] INSERT 완료
# ✅ [3510000 ~ 3520000] INSERT 완료
# ✅ [3520000 ~ 3530000] INSERT 완료
# ✅ [3530000 ~ 3540000] INSERT 완료
# ✅ [3540000 ~ 3550000] INSERT 완료
# ✅ [3550000 ~ 3560000] INSERT 완료
# ✅ [3560000 ~ 3570000] INSERT 완료
# ✅ [3570000 ~ 3580000] INSERT 완료
# ✅ [3580000 ~ 3590000] INSERT 완료
# ✅ [3590000 ~ 3600000] INSERT 완료
# ✅ [3600000 ~ 3610000] INSERT 완료
# ✅ [3610000 ~ 3620000] INSERT 완료
# ✅ [3620000 ~ 3630000] INSERT 완료
# ✅ [3630000 ~ 3640000] INSERT 완료
# ✅ [3640000 ~ 3650000] INSERT 완료
# ✅ [3650000 ~ 3660000] INSERT 완료
# ✅ [3660000 ~ 3670000] INSERT 완료
# ✅ [3670000 ~ 3680000] INSERT 완료
# ✅ [3680000 ~ 3690000] INSERT 완료
# ✅ [3690000 ~ 3700000] INSERT 완료
# ✅ [3700000 ~ 3710000] INSERT 완료
# ✅ [3710000 ~ 3720000] INSERT 완료
# ✅ [3720000 ~ 3730000] INSERT 완료
# ✅ [3730000 ~ 3740000] INSERT 완료
# ✅ [3740000 ~ 3750000] INSERT 완료
# ✅ [3750000 ~ 3760000] INSERT 완료
# ✅ [3760000 ~ 3770000] INSERT 완료
# ✅ [3770000 ~ 3780000] INSERT 완료
# ✅ [3780000 ~ 3790000] INSERT 완료
# ✅ [3790000 ~ 3800000] INSERT 완료
# ✅ [3800000 ~ 3810000] INSERT 완료
# ✅ [3810000 ~ 3820000] INSERT 완료
# ✅ [3820000 ~ 3830000] INSERT 완료
# ✅ [3830000 ~ 3840000] INSERT 완료
# ✅ [3840000 ~ 3850000] INSERT 완료
# ✅ [3850000 ~ 3860000] INSERT 완료
# ✅ [3860000 ~ 3870000] INSERT 완료
# ✅ [3870000 ~ 3880000] INSERT 완료
# ✅ [3880000 ~ 3890000] INSERT 완료
# ✅ [3890000 ~ 3900000] INSERT 완료
# ✅ [3900000 ~ 3910000] INSERT 완료
# ✅ [3910000 ~ 3920000] INSERT 완료
# ✅ [3920000 ~ 3930000] INSERT 완료
# ✅ [3930000 ~ 3940000] INSERT 완료
# ✅ [3940000 ~ 3950000] INSERT 완료
# ✅ [3950000 ~ 3960000] INSERT 완료
# ✅ [3960000 ~ 3970000] INSERT 완료
# ✅ [3970000 ~ 3980000] INSERT 완료
# ✅ [3980000 ~ 3990000] INSERT 완료
# ✅ [3990000 ~ 4000000] INSERT 완료
# ✅ [4000000 ~ 4010000] INSERT 완료
# ✅ [4010000 ~ 4020000] INSERT 완료
# ✅ [4020000 ~ 4030000] INSERT 완료
# ✅ [4030000 ~ 4040000] INSERT 완료
# ✅ [4040000 ~ 4050000] INSERT 완료
# ✅ [4050000 ~ 4060000] INSERT 완료
# ✅ [4060000 ~ 4070000] INSERT 완료
# ✅ [4070000 ~ 4080000] INSERT 완료
# ✅ [4080000 ~ 4090000] INSERT 완료
# ✅ [4090000 ~ 4100000] INSERT 완료
# ✅ [4100000 ~ 4110000] INSERT 완료
# ✅ [4110000 ~ 4120000] INSERT 완료
# ✅ [4120000 ~ 4130000] INSERT 완료
# ✅ [4130000 ~ 4140000] INSERT 완료
# ✅ [4140000 ~ 4150000] INSERT 완료
# ✅ [4150000 ~ 4160000] INSERT 완료
# ✅ [4160000 ~ 4170000] INSERT 완료
# ✅ [4170000 ~ 4180000] INSERT 완료
# ✅ [4180000 ~ 4190000] INSERT 완료
# ✅ [4190000 ~ 4200000] INSERT 완료
# ✅ [4200000 ~ 4210000] INSERT 완료
# ✅ [4210000 ~ 4220000] INSERT 완료
# ✅ [4220000 ~ 4230000] INSERT 완료
# ✅ [4230000 ~ 4240000] INSERT 완료
# ✅ [4240000 ~ 4250000] INSERT 완료
# ✅ [4250000 ~ 4260000] INSERT 완료
# ✅ [4260000 ~ 4270000] INSERT 완료
# ✅ [4270000 ~ 4280000] INSERT 완료
# ✅ [4280000 ~ 4290000] INSERT 완료
# ✅ [4290000 ~ 4300000] INSERT 완료
# ✅ [4300000 ~ 4310000] INSERT 완료
# ✅ [4310000 ~ 4320000] INSERT 완료
# ✅ [4320000 ~ 4330000] INSERT 완료
# ✅ [4330000 ~ 4340000] INSERT 완료
# ✅ [4340000 ~ 4350000] INSERT 완료
# ✅ [4350000 ~ 4360000] INSERT 완료
# ✅ [4360000 ~ 4370000] INSERT 완료
# ✅ [4370000 ~ 4380000] INSERT 완료
# ✅ [4380000 ~ 4390000] INSERT 완료
# ✅ [4390000 ~ 4400000] INSERT 완료
# ✅ [4400000 ~ 4410000] INSERT 완료
# ✅ [4410000 ~ 4420000] INSERT 완료
# ✅ [4420000 ~ 4430000] INSERT 완료
# ✅ [4430000 ~ 4440000] INSERT 완료
# ✅ [4440000 ~ 4450000] INSERT 완료
# ✅ [4450000 ~ 4460000] INSERT 완료
# ✅ [4460000 ~ 4470000] INSERT 완료
# ✅ [4470000 ~ 4480000] INSERT 완료
# ✅ [4480000 ~ 4490000] INSERT 완료
# ✅ [4490000 ~ 4500000] INSERT 완료
# ✅ [4500000 ~ 4510000] INSERT 완료
# ✅ [4510000 ~ 4520000] INSERT 완료
# ✅ [4520000 ~ 4530000] INSERT 완료
# ✅ [4530000 ~ 4540000] INSERT 완료
# ✅ [4540000 ~ 4550000] INSERT 완료
# ✅ [4550000 ~ 4560000] INSERT 완료
# ✅ [4560000 ~ 4570000] INSERT 완료
# ✅ [4570000 ~ 4580000] INSERT 완료
# ✅ [4580000 ~ 4590000] INSERT 완료
# ✅ [4590000 ~ 4600000] INSERT 완료
# ✅ [4600000 ~ 4610000] INSERT 완료
# ✅ [4610000 ~ 4620000] INSERT 완료
# ✅ [4620000 ~ 4630000] INSERT 완료
# ✅ [4630000 ~ 4640000] INSERT 완료
# ✅ [4640000 ~ 4650000] INSERT 완료
# ✅ [4650000 ~ 4660000] INSERT 완료
# ✅ [4660000 ~ 4670000] INSERT 완료
# ✅ [4670000 ~ 4680000] INSERT 완료
# ✅ [4680000 ~ 4690000] INSERT 완료
# ✅ [4690000 ~ 4700000] INSERT 완료
# ✅ [4700000 ~ 4710000] INSERT 완료
# ✅ [4710000 ~ 4720000] INSERT 완료
# ✅ [4720000 ~ 4730000] INSERT 완료
# ✅ [4730000 ~ 4740000] INSERT 완료
# ✅ [4740000 ~ 4750000] INSERT 완료
# ✅ [4750000 ~ 4760000] INSERT 완료
# ✅ [4760000 ~ 4770000] INSERT 완료
# ✅ [4770000 ~ 4780000] INSERT 완료
# ✅ [4780000 ~ 4790000] INSERT 완료
# ✅ [4790000 ~ 4800000] INSERT 완료
# ✅ [4800000 ~ 4810000] INSERT 완료
# ✅ [4810000 ~ 4820000] INSERT 완료
# ✅ [4820000 ~ 4830000] INSERT 완료
# ✅ [4830000 ~ 4840000] INSERT 완료
# ✅ [4840000 ~ 4850000] INSERT 완료
# ✅ [4850000 ~ 4860000] INSERT 완료
# ✅ [4860000 ~ 4870000] INSERT 완료
# ✅ [4870000 ~ 4880000] INSERT 완료
# ✅ [4880000 ~ 4890000] INSERT 완료
# ✅ [4890000 ~ 4900000] INSERT 완료
# ✅ [4900000 ~ 4910000] INSERT 완료
# ✅ [4910000 ~ 4920000] INSERT 완료
# ✅ [4920000 ~ 4930000] INSERT 완료
# ✅ [4930000 ~ 4940000] INSERT 완료
# ✅ [4940000 ~ 4950000] INSERT 완료
# ✅ [4950000 ~ 4960000] INSERT 완료
# ✅ [4960000 ~ 4970000] INSERT 완료
# ✅ [4970000 ~ 4980000] INSERT 완료
# ✅ [4980000 ~ 4990000] INSERT 완료
# ✅ [4990000 ~ 5000000] INSERT 완료
# ✅ [5000000 ~ 5010000] INSERT 완료
# ✅ [5010000 ~ 5020000] INSERT 완료
# ✅ [5020000 ~ 5030000] INSERT 완료
# ✅ [5030000 ~ 5040000] INSERT 완료
# ✅ [5040000 ~ 5050000] INSERT 완료
# ✅ [5050000 ~ 5060000] INSERT 완료
# ✅ [5060000 ~ 5070000] INSERT 완료
# ✅ [5070000 ~ 5080000] INSERT 완료
# ✅ [5080000 ~ 5090000] INSERT 완료
# ✅ [5090000 ~ 5100000] INSERT 완료
# ✅ [5100000 ~ 5110000] INSERT 완료
# ✅ [5110000 ~ 5120000] INSERT 완료
# ✅ [5120000 ~ 5130000] INSERT 완료
# ✅ [5130000 ~ 5140000] INSERT 완료
# ✅ [5140000 ~ 5150000] INSERT 완료
# ✅ [5150000 ~ 5160000] INSERT 완료
# ✅ [5160000 ~ 5170000] INSERT 완료
# ✅ [5170000 ~ 5180000] INSERT 완료
# ✅ [5180000 ~ 5190000] INSERT 완료
# ✅ [5190000 ~ 5200000] INSERT 완료
# ✅ [5200000 ~ 5210000] INSERT 완료
# ✅ [5210000 ~ 5220000] INSERT 완료
# ✅ [5220000 ~ 5230000] INSERT 완료
# ✅ [5230000 ~ 5240000] INSERT 완료
# ✅ [5240000 ~ 5250000] INSERT 완료
# ✅ [5250000 ~ 5260000] INSERT 완료
# ✅ [5260000 ~ 5270000] INSERT 완료
# ✅ [5270000 ~ 5280000] INSERT 완료
# ✅ [5280000 ~ 5290000] INSERT 완료
# ✅ [5290000 ~ 5300000] INSERT 완료
# ✅ [5300000 ~ 5310000] INSERT 완료
# ✅ [5310000 ~ 5320000] INSERT 완료
# ✅ [5320000 ~ 5330000] INSERT 완료
# ✅ [5330000 ~ 5340000] INSERT 완료
# ✅ [5340000 ~ 5350000] INSERT 완료
# ✅ [5350000 ~ 5360000] INSERT 완료
# ✅ [5360000 ~ 5370000] INSERT 완료
# ✅ [5370000 ~ 5380000] INSERT 완료
# ✅ [5380000 ~ 5390000] INSERT 완료
# ✅ [5390000 ~ 5400000] INSERT 완료
# ✅ [5400000 ~ 5410000] INSERT 완료
# ✅ [5410000 ~ 5420000] INSERT 완료
# ✅ [5420000 ~ 5430000] INSERT 완료
# ✅ [5430000 ~ 5440000] INSERT 완료
# ✅ [5440000 ~ 5450000] INSERT 완료
# ✅ [5450000 ~ 5460000] INSERT 완료
# ✅ [5460000 ~ 5470000] INSERT 완료
# ✅ [5470000 ~ 5480000] INSERT 완료
# ✅ [5480000 ~ 5490000] INSERT 완료
# ✅ [5490000 ~ 5500000] INSERT 완료
# ✅ [5500000 ~ 5510000] INSERT 완료
# ✅ [5510000 ~ 5520000] INSERT 완료
# ✅ [5520000 ~ 5530000] INSERT 완료
# ✅ [5530000 ~ 5540000] INSERT 완료
# ✅ [5540000 ~ 5550000] INSERT 완료
# ✅ [5550000 ~ 5560000] INSERT 완료
# ✅ [5560000 ~ 5570000] INSERT 완료
# ✅ [5570000 ~ 5580000] INSERT 완료
# ✅ [5580000 ~ 5590000] INSERT 완료
# ✅ [5590000 ~ 5600000] INSERT 완료
# ✅ [5600000 ~ 5610000] INSERT 완료
# ✅ [5610000 ~ 5620000] INSERT 완료
# ✅ [5620000 ~ 5630000] INSERT 완료
# ✅ [5630000 ~ 5640000] INSERT 완료
# ✅ [5640000 ~ 5650000] INSERT 완료
# ✅ [5650000 ~ 5660000] INSERT 완료
# ✅ [5660000 ~ 5670000] INSERT 완료
# ✅ [5670000 ~ 5680000] INSERT 완료
# ✅ [5680000 ~ 5690000] INSERT 완료
# ✅ [5690000 ~ 5700000] INSERT 완료
# ✅ [5700000 ~ 5710000] INSERT 완료
# ✅ [5710000 ~ 5720000] INSERT 완료
# ✅ [5720000 ~ 5730000] INSERT 완료
# ✅ [5730000 ~ 5740000] INSERT 완료
# ✅ [5740000 ~ 5750000] INSERT 완료
# ✅ [5750000 ~ 5760000] INSERT 완료
# ✅ [5760000 ~ 5770000] INSERT 완료
# ✅ [5770000 ~ 5780000] INSERT 완료
# ✅ [5780000 ~ 5790000] INSERT 완료
# ✅ [5790000 ~ 5800000] INSERT 완료
# ✅ [5800000 ~ 5810000] INSERT 완료
# ✅ [5810000 ~ 5820000] INSERT 완료
# ✅ [5820000 ~ 5830000] INSERT 완료
# ✅ [5830000 ~ 5840000] INSERT 완료
# ✅ [5840000 ~ 5850000] INSERT 완료
# ✅ [5850000 ~ 5860000] INSERT 완료
# ✅ [5860000 ~ 5870000] INSERT 완료
# ✅ [5870000 ~ 5880000] INSERT 완료
# ✅ [5880000 ~ 5890000] INSERT 완료
# ✅ [5890000 ~ 5900000] INSERT 완료
# ✅ [5900000 ~ 5910000] INSERT 완료
# ✅ [5910000 ~ 5920000] INSERT 완료
# ✅ [5920000 ~ 5930000] INSERT 완료
# ✅ [5930000 ~ 5940000] INSERT 완료
# ✅ [5940000 ~ 5950000] INSERT 완료
# ✅ [5950000 ~ 5960000] INSERT 완료
# ✅ [5960000 ~ 5970000] INSERT 완료
# ✅ [5970000 ~ 5980000] INSERT 완료
# ✅ [5980000 ~ 5990000] INSERT 완료
# ✅ [5990000 ~ 6000000] INSERT 완료
# ✅ [6000000 ~ 6010000] INSERT 완료
# ✅ [6010000 ~ 6020000] INSERT 완료
# ✅ [6020000 ~ 6030000] INSERT 완료
# ✅ [6030000 ~ 6040000] INSERT 완료
# ✅ [6040000 ~ 6050000] INSERT 완료
# ✅ [6050000 ~ 6060000] INSERT 완료
# ✅ [6060000 ~ 6070000] INSERT 완료
# ✅ [6070000 ~ 6080000] INSERT 완료
# ✅ [6080000 ~ 6090000] INSERT 완료
# ✅ [6090000 ~ 6100000] INSERT 완료
# ✅ [6100000 ~ 6110000] INSERT 완료
# ✅ [6110000 ~ 6120000] INSERT 완료
# ✅ [6120000 ~ 6130000] INSERT 완료
# ✅ [6130000 ~ 6140000] INSERT 완료
# ✅ [6140000 ~ 6150000] INSERT 완료
# ✅ [6150000 ~ 6160000] INSERT 완료
# ✅ [6160000 ~ 6170000] INSERT 완료
# ✅ [6170000 ~ 6180000] INSERT 완료
# ✅ [6180000 ~ 6190000] INSERT 완료
# ✅ [6190000 ~ 6200000] INSERT 완료
# ✅ [6200000 ~ 6210000] INSERT 완료
# ✅ [6210000 ~ 6220000] INSERT 완료
# ✅ [6220000 ~ 6230000] INSERT 완료
# ✅ [6230000 ~ 6240000] INSERT 완료
# ✅ [6240000 ~ 6250000] INSERT 완료
# ✅ [6250000 ~ 6260000] INSERT 완료
# ✅ [6260000 ~ 6270000] INSERT 완료
# ✅ [6270000 ~ 6280000] INSERT 완료
# ✅ [6280000 ~ 6290000] INSERT 완료
# ✅ [6290000 ~ 6300000] INSERT 완료
# ✅ [6300000 ~ 6310000] INSERT 완료
# ✅ [6310000 ~ 6320000] INSERT 완료
# ✅ [6320000 ~ 6330000] INSERT 완료
# ✅ [6330000 ~ 6340000] INSERT 완료
# ✅ [6340000 ~ 6350000] INSERT 완료
# ✅ [6350000 ~ 6360000] INSERT 완료
# ✅ [6360000 ~ 6370000] INSERT 완료
# ✅ [6370000 ~ 6380000] INSERT 완료
# ✅ [6380000 ~ 6390000] INSERT 완료
# ✅ [6390000 ~ 6400000] INSERT 완료
# ✅ [6400000 ~ 6410000] INSERT 완료
# ✅ [6410000 ~ 6420000] INSERT 완료
# ✅ [6420000 ~ 6430000] INSERT 완료
# ✅ [6430000 ~ 6440000] INSERT 완료
# ✅ [6440000 ~ 6450000] INSERT 완료
# ✅ [6450000 ~ 6460000] INSERT 완료
# ✅ [6460000 ~ 6470000] INSERT 완료
# ✅ [6470000 ~ 6480000] INSERT 완료
# ✅ [6480000 ~ 6490000] INSERT 완료
# ✅ [6490000 ~ 6500000] INSERT 완료
# ✅ [6500000 ~ 6510000] INSERT 완료
# ✅ [6510000 ~ 6520000] INSERT 완료
# ✅ [6520000 ~ 6530000] INSERT 완료
# ✅ [6530000 ~ 6540000] INSERT 완료
# ✅ [6540000 ~ 6550000] INSERT 완료
# ✅ [6550000 ~ 6560000] INSERT 완료
# ✅ [6560000 ~ 6570000] INSERT 완료
# ✅ [6570000 ~ 6580000] INSERT 완료
# ✅ [6580000 ~ 6590000] INSERT 완료
# ✅ [6590000 ~ 6600000] INSERT 완료
# ✅ [6600000 ~ 6610000] INSERT 완료
# ✅ [6610000 ~ 6620000] INSERT 완료
# ✅ [6620000 ~ 6630000] INSERT 완료
# ✅ [6630000 ~ 6640000] INSERT 완료
# ✅ [6640000 ~ 6650000] INSERT 완료
# ✅ [6650000 ~ 6660000] INSERT 완료
# ✅ [6660000 ~ 6670000] INSERT 완료
# ✅ [6670000 ~ 6680000] INSERT 완료
# ✅ [6680000 ~ 6690000] INSERT 완료
# ✅ [6690000 ~ 6700000] INSERT 완료
# ✅ [6700000 ~ 6710000] INSERT 완료
# ✅ [6710000 ~ 6720000] INSERT 완료
# ✅ [6720000 ~ 6730000] INSERT 완료
# ✅ [6730000 ~ 6740000] INSERT 완료
# ✅ [6740000 ~ 6750000] INSERT 완료
# ✅ [6750000 ~ 6760000] INSERT 완료
# ✅ [6760000 ~ 6770000] INSERT 완료
# ✅ [6770000 ~ 6780000] INSERT 완료
# ✅ [6780000 ~ 6790000] INSERT 완료
# ✅ [6790000 ~ 6800000] INSERT 완료
# ✅ [6800000 ~ 6810000] INSERT 완료
# ✅ [6810000 ~ 6820000] INSERT 완료
# ✅ [6820000 ~ 6830000] INSERT 완료
# ✅ [6830000 ~ 6840000] INSERT 완료
# ✅ [6840000 ~ 6850000] INSERT 완료
# ✅ [6850000 ~ 6860000] INSERT 완료
# ✅ [6860000 ~ 6870000] INSERT 완료
# ✅ [6870000 ~ 6880000] INSERT 완료
# ✅ [6880000 ~ 6890000] INSERT 완료
# ✅ [6890000 ~ 6900000] INSERT 완료
# ✅ [6900000 ~ 6910000] INSERT 완료
# ✅ [6910000 ~ 6920000] INSERT 완료
# ✅ [6920000 ~ 6930000] INSERT 완료
# ✅ [6930000 ~ 6940000] INSERT 완료
# ✅ [6940000 ~ 6950000] INSERT 완료
# ✅ [6950000 ~ 6960000] INSERT 완료
# ✅ [6960000 ~ 6970000] INSERT 완료
# ✅ [6970000 ~ 6980000] INSERT 완료
# ✅ [6980000 ~ 6990000] INSERT 완료
# ✅ [6990000 ~ 7000000] INSERT 완료
# ✅ [7000000 ~ 7010000] INSERT 완료
# ✅ [7010000 ~ 7020000] INSERT 완료
# ✅ [7020000 ~ 7030000] INSERT 완료
# ✅ [7030000 ~ 7040000] INSERT 완료
# ✅ [7040000 ~ 7050000] INSERT 완료
# ✅ [7050000 ~ 7060000] INSERT 완료
# ✅ [7060000 ~ 7070000] INSERT 완료
# ✅ [7070000 ~ 7080000] INSERT 완료
# ✅ [7080000 ~ 7090000] INSERT 완료
# ✅ [7090000 ~ 7100000] INSERT 완료
# ✅ [7100000 ~ 7110000] INSERT 완료
# ✅ [7110000 ~ 7120000] INSERT 완료
# ✅ [7120000 ~ 7130000] INSERT 완료
# ✅ [7130000 ~ 7140000] INSERT 완료
# ✅ [7140000 ~ 7150000] INSERT 완료
# ✅ [7150000 ~ 7160000] INSERT 완료
# ✅ [7160000 ~ 7170000] INSERT 완료
# ✅ [7170000 ~ 7180000] INSERT 완료
# ✅ [7180000 ~ 7190000] INSERT 완료
# ✅ [7190000 ~ 7200000] INSERT 완료
# ✅ [7200000 ~ 7210000] INSERT 완료
# ✅ [7210000 ~ 7220000] INSERT 완료
# ✅ [7220000 ~ 7230000] INSERT 완료
# ✅ [7230000 ~ 7240000] INSERT 완료
# ✅ [7240000 ~ 7250000] INSERT 완료
# ✅ [7250000 ~ 7260000] INSERT 완료
# ✅ [7260000 ~ 7270000] INSERT 완료
# ✅ [7270000 ~ 7280000] INSERT 완료
# ✅ [7280000 ~ 7290000] INSERT 완료
# ✅ [7290000 ~ 7300000] INSERT 완료
# ✅ [7300000 ~ 7310000] INSERT 완료
# ✅ [7310000 ~ 7320000] INSERT 완료
# ✅ [7320000 ~ 7330000] INSERT 완료
# ✅ [7330000 ~ 7340000] INSERT 완료
# ✅ [7340000 ~ 7350000] INSERT 완료
# ✅ [7350000 ~ 7360000] INSERT 완료
# ✅ [7360000 ~ 7370000] INSERT 완료
# ✅ [7370000 ~ 7380000] INSERT 완료
# ✅ [7380000 ~ 7390000] INSERT 완료
# ✅ [7390000 ~ 7400000] INSERT 완료
# ✅ [7400000 ~ 7410000] INSERT 완료
# ✅ [7410000 ~ 7420000] INSERT 완료
# ✅ [7420000 ~ 7430000] INSERT 완료
# ✅ [7430000 ~ 7440000] INSERT 완료
# ✅ [7440000 ~ 7450000] INSERT 완료
# ✅ [7450000 ~ 7460000] INSERT 완료
# ✅ [7460000 ~ 7470000] INSERT 완료
# ✅ [7470000 ~ 7480000] INSERT 완료
# ✅ [7480000 ~ 7490000] INSERT 완료
# ✅ [7490000 ~ 7500000] INSERT 완료
# ✅ [7500000 ~ 7510000] INSERT 완료
# ✅ [7510000 ~ 7520000] INSERT 완료
# ✅ [7520000 ~ 7530000] INSERT 완료
# ✅ [7530000 ~ 7540000] INSERT 완료
# ✅ [7540000 ~ 7550000] INSERT 완료
# ✅ [7550000 ~ 7560000] INSERT 완료
# ✅ [7560000 ~ 7570000] INSERT 완료
# ✅ [7570000 ~ 7580000] INSERT 완료
# ✅ [7580000 ~ 7590000] INSERT 완료
# ✅ [7590000 ~ 7600000] INSERT 완료
# ✅ [7600000 ~ 7610000] INSERT 완료
# ✅ [7610000 ~ 7620000] INSERT 완료
# ✅ [7620000 ~ 7630000] INSERT 완료
# ✅ [7630000 ~ 7640000] INSERT 완료
# ✅ [7640000 ~ 7650000] INSERT 완료
# ✅ [7650000 ~ 7660000] INSERT 완료
# ✅ [7660000 ~ 7670000] INSERT 완료
# ✅ [7670000 ~ 7680000] INSERT 완료
# ✅ [7680000 ~ 7690000] INSERT 완료
# ✅ [7690000 ~ 7700000] INSERT 완료
# ✅ [7700000 ~ 7710000] INSERT 완료
# ✅ [7710000 ~ 7720000] INSERT 완료
# ✅ [7720000 ~ 7730000] INSERT 완료
# ✅ [7730000 ~ 7740000] INSERT 완료
# ✅ [7740000 ~ 7750000] INSERT 완료
# ✅ [7750000 ~ 7760000] INSERT 완료
# ✅ [7760000 ~ 7770000] INSERT 완료
# ✅ [7770000 ~ 7780000] INSERT 완료
# ✅ [7780000 ~ 7790000] INSERT 완료
# ✅ [7790000 ~ 7800000] INSERT 완료
# ✅ [7800000 ~ 7810000] INSERT 완료
# ✅ [7810000 ~ 7820000] INSERT 완료
# ✅ [7820000 ~ 7830000] INSERT 완료
# ✅ [7830000 ~ 7840000] INSERT 완료
# ✅ [7840000 ~ 7850000] INSERT 완료
# ✅ [7850000 ~ 7860000] INSERT 완료
# ✅ [7860000 ~ 7870000] INSERT 완료
# ✅ [7870000 ~ 7880000] INSERT 완료
# ✅ [7880000 ~ 7890000] INSERT 완료
# ✅ [7890000 ~ 7900000] INSERT 완료
# ✅ [7900000 ~ 7910000] INSERT 완료
# ✅ [7910000 ~ 7920000] INSERT 완료
# ✅ [7920000 ~ 7930000] INSERT 완료
# ✅ [7930000 ~ 7940000] INSERT 완료
# ✅ [7940000 ~ 7950000] INSERT 완료
# ✅ [7950000 ~ 7960000] INSERT 완료
# ✅ [7960000 ~ 7970000] INSERT 완료
# ✅ [7970000 ~ 7980000] INSERT 완료
# ✅ [7980000 ~ 7990000] INSERT 완료
# ✅ [7990000 ~ 8000000] INSERT 완료
# ✅ [8000000 ~ 8010000] INSERT 완료
# ✅ [8010000 ~ 8020000] INSERT 완료
# ✅ [8020000 ~ 8030000] INSERT 완료
# ✅ [8030000 ~ 8040000] INSERT 완료
# ✅ [8040000 ~ 8050000] INSERT 완료
# ✅ [8050000 ~ 8060000] INSERT 완료
# ✅ [8060000 ~ 8070000] INSERT 완료
# ✅ [8070000 ~ 8080000] INSERT 완료
# ✅ [8080000 ~ 8090000] INSERT 완료
# ✅ [8090000 ~ 8100000] INSERT 완료
# ✅ [8100000 ~ 8110000] INSERT 완료
# ✅ [8110000 ~ 8120000] INSERT 완료
# ✅ [8120000 ~ 8130000] INSERT 완료
# ✅ [8130000 ~ 8140000] INSERT 완료
# ✅ [8140000 ~ 8150000] INSERT 완료
# ✅ [8150000 ~ 8160000] INSERT 완료
# ✅ [8160000 ~ 8170000] INSERT 완료
# ✅ [8170000 ~ 8180000] INSERT 완료
# ✅ [8180000 ~ 8190000] INSERT 완료
# ✅ [8190000 ~ 8200000] INSERT 완료
# ✅ [8200000 ~ 8210000] INSERT 완료
# ✅ [8210000 ~ 8220000] INSERT 완료
# ✅ [8220000 ~ 8230000] INSERT 완료
# ✅ [8230000 ~ 8240000] INSERT 완료
# ✅ [8240000 ~ 8250000] INSERT 완료
# ✅ [8250000 ~ 8260000] INSERT 완료
# ✅ [8260000 ~ 8270000] INSERT 완료
# ✅ [8270000 ~ 8280000] INSERT 완료
# ✅ [8280000 ~ 8290000] INSERT 완료
# ✅ [8290000 ~ 8300000] INSERT 완료
# ✅ [8300000 ~ 8310000] INSERT 완료
# ✅ [8310000 ~ 8320000] INSERT 완료
# ✅ [8320000 ~ 8330000] INSERT 완료
# ✅ [8330000 ~ 8340000] INSERT 완료
# ✅ [8340000 ~ 8350000] INSERT 완료
# ✅ [8350000 ~ 8360000] INSERT 완료
# ✅ [8360000 ~ 8370000] INSERT 완료
# ✅ [8370000 ~ 8380000] INSERT 완료
# ✅ [8380000 ~ 8390000] INSERT 완료
# ✅ [8390000 ~ 8400000] INSERT 완료
# ✅ [8400000 ~ 8410000] INSERT 완료
# ✅ [8410000 ~ 8420000] INSERT 완료
# ✅ [8420000 ~ 8430000] INSERT 완료
# ✅ [8430000 ~ 8440000] INSERT 완료
# ✅ [8440000 ~ 8450000] INSERT 완료
# ✅ [8450000 ~ 8460000] INSERT 완료
# ✅ [8460000 ~ 8470000] INSERT 완료
# ✅ [8470000 ~ 8480000] INSERT 완료
# ✅ [8480000 ~ 8490000] INSERT 완료
# ✅ [8490000 ~ 8500000] INSERT 완료
# ✅ [8500000 ~ 8510000] INSERT 완료
# ✅ [8510000 ~ 8520000] INSERT 완료
# ✅ [8520000 ~ 8530000] INSERT 완료
# ✅ [8530000 ~ 8540000] INSERT 완료
# ✅ [8540000 ~ 8550000] INSERT 완료
# ✅ [8550000 ~ 8560000] INSERT 완료
# ✅ [8560000 ~ 8570000] INSERT 완료
# ✅ [8570000 ~ 8580000] INSERT 완료
# ✅ [8580000 ~ 8590000] INSERT 완료
# ✅ [8590000 ~ 8600000] INSERT 완료
# ✅ [8600000 ~ 8610000] INSERT 완료
# ✅ [8610000 ~ 8620000] INSERT 완료
# ✅ [8620000 ~ 8630000] INSERT 완료
# ✅ [8630000 ~ 8640000] INSERT 완료
# ✅ [8640000 ~ 8650000] INSERT 완료
# ✅ [8650000 ~ 8660000] INSERT 완료
# ✅ [8660000 ~ 8670000] INSERT 완료
# ✅ [8670000 ~ 8680000] INSERT 완료
# ✅ [8680000 ~ 8690000] INSERT 완료
# ✅ [8690000 ~ 8700000] INSERT 완료
# ✅ [8700000 ~ 8710000] INSERT 완료
# ✅ [8710000 ~ 8720000] INSERT 완료
# ✅ [8720000 ~ 8730000] INSERT 완료
# ✅ [8730000 ~ 8740000] INSERT 완료
# ✅ [8740000 ~ 8750000] INSERT 완료
# ✅ [8750000 ~ 8760000] INSERT 완료
# ✅ [8760000 ~ 8770000] INSERT 완료
# ✅ [8770000 ~ 8780000] INSERT 완료
# ✅ [8780000 ~ 8790000] INSERT 완료
# ✅ [8790000 ~ 8800000] INSERT 완료
# ✅ [8800000 ~ 8810000] INSERT 완료
# ✅ [8810000 ~ 8820000] INSERT 완료
# ✅ [8820000 ~ 8830000] INSERT 완료
# ✅ [8830000 ~ 8840000] INSERT 완료
# ✅ [8840000 ~ 8850000] INSERT 완료
# ✅ [8850000 ~ 8860000] INSERT 완료
# ✅ [8860000 ~ 8870000] INSERT 완료
# ✅ [8870000 ~ 8880000] INSERT 완료
# ✅ [8880000 ~ 8890000] INSERT 완료
# ✅ [8890000 ~ 8900000] INSERT 완료
# ✅ [8900000 ~ 8910000] INSERT 완료
# ✅ [8910000 ~ 8920000] INSERT 완료
# ✅ [8920000 ~ 8930000] INSERT 완료
# ✅ [8930000 ~ 8940000] INSERT 완료
# ✅ [8940000 ~ 8950000] INSERT 완료
# ✅ [8950000 ~ 8960000] INSERT 완료
# ✅ [8960000 ~ 8970000] INSERT 완료
# ✅ [8970000 ~ 8980000] INSERT 완료
# ✅ [8980000 ~ 8990000] INSERT 완료
# ✅ [8990000 ~ 9000000] INSERT 완료
# ✅ [9000000 ~ 9010000] INSERT 완료
# ✅ [9010000 ~ 9020000] INSERT 완료
# ✅ [9020000 ~ 9030000] INSERT 완료
# ✅ [9030000 ~ 9040000] INSERT 완료
# ✅ [9040000 ~ 9050000] INSERT 완료
# ✅ [9050000 ~ 9060000] INSERT 완료
# ✅ [9060000 ~ 9070000] INSERT 완료
# ✅ [9070000 ~ 9080000] INSERT 완료
# ✅ [9080000 ~ 9090000] INSERT 완료
# ✅ [9090000 ~ 9100000] INSERT 완료
# ✅ [9100000 ~ 9110000] INSERT 완료
# ✅ [9110000 ~ 9120000] INSERT 완료
# ✅ [9120000 ~ 9130000] INSERT 완료
# ✅ [9130000 ~ 9140000] INSERT 완료
# ✅ [9140000 ~ 9150000] INSERT 완료
# ✅ [9150000 ~ 9160000] INSERT 완료
# ✅ [9160000 ~ 9170000] INSERT 완료
# ✅ [9170000 ~ 9180000] INSERT 완료
# ✅ [9180000 ~ 9190000] INSERT 완료
# ✅ [9190000 ~ 9200000] INSERT 완료
# ✅ [9200000 ~ 9210000] INSERT 완료
# ✅ [9210000 ~ 9220000] INSERT 완료
# ✅ [9220000 ~ 9230000] INSERT 완료
# ✅ [9230000 ~ 9240000] INSERT 완료
# ✅ [9240000 ~ 9250000] INSERT 완료
# ✅ [9250000 ~ 9260000] INSERT 완료
# ✅ [9260000 ~ 9270000] INSERT 완료
# ✅ [9270000 ~ 9280000] INSERT 완료
# ✅ [9280000 ~ 9290000] INSERT 완료
# ✅ [9290000 ~ 9300000] INSERT 완료
# ✅ [9300000 ~ 9310000] INSERT 완료
# ✅ [9310000 ~ 9320000] INSERT 완료
# ✅ [9320000 ~ 9330000] INSERT 완료
# ✅ [9330000 ~ 9340000] INSERT 완료
# ✅ [9340000 ~ 9350000] INSERT 완료
# ✅ [9350000 ~ 9360000] INSERT 완료
# ✅ [9360000 ~ 9370000] INSERT 완료
# ✅ [9370000 ~ 9380000] INSERT 완료
# ✅ [9380000 ~ 9390000] INSERT 완료
# ✅ [9390000 ~ 9400000] INSERT 완료
# ✅ [9400000 ~ 9410000] INSERT 완료
# ✅ [9410000 ~ 9420000] INSERT 완료
# ✅ [9420000 ~ 9430000] INSERT 완료
# ✅ [9430000 ~ 9440000] INSERT 완료
# ✅ [9440000 ~ 9450000] INSERT 완료
# ✅ [9450000 ~ 9460000] INSERT 완료
# ✅ [9460000 ~ 9470000] INSERT 완료
# ✅ [9470000 ~ 9480000] INSERT 완료
# ✅ [9480000 ~ 9490000] INSERT 완료
# ✅ [9490000 ~ 9500000] INSERT 완료
# ✅ [9500000 ~ 9510000] INSERT 완료
# ✅ [9510000 ~ 9520000] INSERT 완료
# ✅ [9520000 ~ 9530000] INSERT 완료
# ✅ [9530000 ~ 9540000] INSERT 완료
# ✅ [9540000 ~ 9550000] INSERT 완료
# ✅ [9550000 ~ 9560000] INSERT 완료
# ✅ [9560000 ~ 9570000] INSERT 완료
# ✅ [9570000 ~ 9580000] INSERT 완료
# ✅ [9580000 ~ 9590000] INSERT 완료
# ✅ [9590000 ~ 9600000] INSERT 완료
# ✅ [9600000 ~ 9610000] INSERT 완료
# ✅ [9610000 ~ 9620000] INSERT 완료
# ✅ [9620000 ~ 9630000] INSERT 완료
# ✅ [9630000 ~ 9640000] INSERT 완료
# ✅ [9640000 ~ 9650000] INSERT 완료
# ✅ [9650000 ~ 9660000] INSERT 완료
# ✅ [9660000 ~ 9670000] INSERT 완료
# ✅ [9670000 ~ 9680000] INSERT 완료
# ✅ [9680000 ~ 9690000] INSERT 완료
# ✅ [9690000 ~ 9700000] INSERT 완료
# ✅ [9700000 ~ 9710000] INSERT 완료
# ✅ [9710000 ~ 9720000] INSERT 완료
# ✅ [9720000 ~ 9730000] INSERT 완료
# ✅ [9730000 ~ 9740000] INSERT 완료
# ✅ [9740000 ~ 9750000] INSERT 완료
# ✅ [9750000 ~ 9760000] INSERT 완료
# ✅ [9760000 ~ 9770000] INSERT 완료
# ✅ [9770000 ~ 9780000] INSERT 완료
# ✅ [9780000 ~ 9790000] INSERT 완료
# ✅ [9790000 ~ 9800000] INSERT 완료
# ✅ [9800000 ~ 9810000] INSERT 완료
# ✅ [9810000 ~ 9820000] INSERT 완료
# ✅ [9820000 ~ 9830000] INSERT 완료
# ✅ [9830000 ~ 9840000] INSERT 완료
# ✅ [9840000 ~ 9850000] INSERT 완료
# ✅ [9850000 ~ 9860000] INSERT 완료
# ✅ [9860000 ~ 9870000] INSERT 완료
# ✅ [9870000 ~ 9880000] INSERT 완료
# ✅ [9880000 ~ 9890000] INSERT 완료
# ✅ [9890000 ~ 9900000] INSERT 완료
# ✅ [9900000 ~ 9910000] INSERT 완료
# ✅ [9910000 ~ 9920000] INSERT 완료
# ✅ [9920000 ~ 9930000] INSERT 완료
# ✅ [9930000 ~ 9940000] INSERT 완료
# ✅ [9940000 ~ 9950000] INSERT 완료
# ✅ [9950000 ~ 9960000] INSERT 완료
# ✅ [9960000 ~ 9970000] INSERT 완료
# ✅ [9970000 ~ 9980000] INSERT 완료
# ✅ [9980000 ~ 9990000] INSERT 완료
# ✅ [9990000 ~ 10000000] INSERT 완료
# ✅ [10000000 ~ 10010000] INSERT 완료
# ✅ [10010000 ~ 10020000] INSERT 완료
# ✅ [10020000 ~ 10030000] INSERT 완료
# ✅ [10030000 ~ 10040000] INSERT 완료
# ✅ [10040000 ~ 10050000] INSERT 완료
# ✅ [10050000 ~ 10060000] INSERT 완료
# ✅ [10060000 ~ 10070000] INSERT 완료
# ✅ [10070000 ~ 10080000] INSERT 완료
# ✅ [10080000 ~ 10090000] INSERT 완료
# ✅ [10090000 ~ 10100000] INSERT 완료
# ✅ [10100000 ~ 10110000] INSERT 완료
# ✅ [10110000 ~ 10120000] INSERT 완료
# ✅ [10120000 ~ 10130000] INSERT 완료
# ✅ [10130000 ~ 10140000] INSERT 완료
# ✅ [10140000 ~ 10150000] INSERT 완료
# ✅ [10150000 ~ 10160000] INSERT 완료
# ✅ [10160000 ~ 10170000] INSERT 완료
# ✅ [10170000 ~ 10180000] INSERT 완료
# ✅ [10180000 ~ 10190000] INSERT 완료
# ✅ [10190000 ~ 10200000] INSERT 완료
# ✅ [10200000 ~ 10210000] INSERT 완료
# ✅ [10210000 ~ 10220000] INSERT 완료
# ✅ [10220000 ~ 10230000] INSERT 완료
# ✅ [10230000 ~ 10240000] INSERT 완료
# ✅ [10240000 ~ 10250000] INSERT 완료
# ✅ [10250000 ~ 10260000] INSERT 완료
# ✅ [10260000 ~ 10270000] INSERT 완료
# ✅ [10270000 ~ 10280000] INSERT 완료
# ✅ [10280000 ~ 10290000] INSERT 완료
# ✅ [10290000 ~ 10300000] INSERT 완료
# ✅ [10300000 ~ 10310000] INSERT 완료
# ✅ [10310000 ~ 10320000] INSERT 완료
# ✅ [10320000 ~ 10330000] INSERT 완료
# ✅ [10330000 ~ 10340000] INSERT 완료
# ✅ [10340000 ~ 10350000] INSERT 완료
# ✅ [10350000 ~ 10360000] INSERT 완료
# ✅ [10360000 ~ 10370000] INSERT 완료
# ✅ [10370000 ~ 10380000] INSERT 완료
# ✅ [10380000 ~ 10390000] INSERT 완료
# ✅ [10390000 ~ 10400000] INSERT 완료
# ✅ [10400000 ~ 10410000] INSERT 완료
# ✅ [10410000 ~ 10420000] INSERT 완료
# ✅ [10420000 ~ 10430000] INSERT 완료
# ✅ [10430000 ~ 10440000] INSERT 완료
# ✅ [10440000 ~ 10450000] INSERT 완료
# ✅ [10450000 ~ 10460000] INSERT 완료
# ✅ [10460000 ~ 10470000] INSERT 완료
# ✅ [10470000 ~ 10480000] INSERT 완료
# ✅ [10480000 ~ 10490000] INSERT 완료
# ✅ [10490000 ~ 10500000] INSERT 완료
# ✅ [10500000 ~ 10510000] INSERT 완료
# ✅ [10510000 ~ 10520000] INSERT 완료
# ✅ [10520000 ~ 10530000] INSERT 완료
# ✅ [10530000 ~ 10540000] INSERT 완료
# ✅ [10540000 ~ 10550000] INSERT 완료
# ✅ [10550000 ~ 10560000] INSERT 완료
# ✅ [10560000 ~ 10570000] INSERT 완료
# ✅ [10570000 ~ 10580000] INSERT 완료
# ✅ [10580000 ~ 10590000] INSERT 완료
# ✅ [10590000 ~ 10600000] INSERT 완료
# ✅ [10600000 ~ 10610000] INSERT 완료
# ✅ [10610000 ~ 10620000] INSERT 완료
# ✅ [10620000 ~ 10630000] INSERT 완료
# ✅ [10630000 ~ 10640000] INSERT 완료
# ✅ [10640000 ~ 10650000] INSERT 완료
# ✅ [10650000 ~ 10660000] INSERT 완료
# ✅ [10660000 ~ 10670000] INSERT 완료
# ✅ [10670000 ~ 10680000] INSERT 완료
# ✅ [10680000 ~ 10690000] INSERT 완료
# ✅ [10690000 ~ 10700000] INSERT 완료
# ✅ [10700000 ~ 10710000] INSERT 완료
# ✅ [10710000 ~ 10720000] INSERT 완료
# ✅ [10720000 ~ 10730000] INSERT 완료
# ✅ [10730000 ~ 10740000] INSERT 완료
# ✅ [10740000 ~ 10750000] INSERT 완료
# ✅ [10750000 ~ 10760000] INSERT 완료
# ✅ [10760000 ~ 10770000] INSERT 완료
# ✅ [10770000 ~ 10780000] INSERT 완료
# ✅ [10780000 ~ 10790000] INSERT 완료
# ✅ [10790000 ~ 10800000] INSERT 완료
# ✅ [10800000 ~ 10810000] INSERT 완료
# ✅ [10810000 ~ 10820000] INSERT 완료
# ✅ [10820000 ~ 10830000] INSERT 완료
# ✅ [10830000 ~ 10840000] INSERT 완료
# ✅ [10840000 ~ 10850000] INSERT 완료
# ✅ [10850000 ~ 10860000] INSERT 완료
# ✅ [10860000 ~ 10870000] INSERT 완료
# ✅ [10870000 ~ 10880000] INSERT 완료
# ✅ [10880000 ~ 10890000] INSERT 완료
# ✅ [10890000 ~ 10900000] INSERT 완료
# ✅ [10900000 ~ 10910000] INSERT 완료
# ✅ [10910000 ~ 10920000] INSERT 완료
# ✅ [10920000 ~ 10930000] INSERT 완료
# ✅ [10930000 ~ 10940000] INSERT 완료
# ✅ [10940000 ~ 10950000] INSERT 완료
# ✅ [10950000 ~ 10960000] INSERT 완료
# ✅ [10960000 ~ 10970000] INSERT 완료
# ✅ [10970000 ~ 10980000] INSERT 완료
# ✅ [10980000 ~ 10990000] INSERT 완료
# ✅ [10990000 ~ 11000000] INSERT 완료
# ✅ [11000000 ~ 11010000] INSERT 완료
# ✅ [11010000 ~ 11020000] INSERT 완료
# ✅ [11020000 ~ 11030000] INSERT 완료
# ✅ [11030000 ~ 11040000] INSERT 완료
# ✅ [11040000 ~ 11050000] INSERT 완료
# ✅ [11050000 ~ 11060000] INSERT 완료
# ✅ [11060000 ~ 11070000] INSERT 완료
# ✅ [11070000 ~ 11080000] INSERT 완료
# ✅ [11080000 ~ 11090000] INSERT 완료
# ✅ [11090000 ~ 11100000] INSERT 완료
# ✅ [11100000 ~ 11110000] INSERT 완료
# ✅ [11110000 ~ 11120000] INSERT 완료
# ✅ [11120000 ~ 11130000] INSERT 완료
# ✅ [11130000 ~ 11140000] INSERT 완료
# ✅ [11140000 ~ 11150000] INSERT 완료
# ✅ [11150000 ~ 11160000] INSERT 완료
# ✅ [11160000 ~ 11170000] INSERT 완료
# ✅ [11170000 ~ 11180000] INSERT 완료
# ✅ [11180000 ~ 11190000] INSERT 완료
# ✅ [11190000 ~ 11200000] INSERT 완료
# ✅ [11200000 ~ 11210000] INSERT 완료
# ✅ [11210000 ~ 11220000] INSERT 완료
# ✅ [11220000 ~ 11230000] INSERT 완료
# ✅ [11230000 ~ 11240000] INSERT 완료
# ✅ [11240000 ~ 11250000] INSERT 완료
# ✅ [11250000 ~ 11260000] INSERT 완료
# ✅ [11260000 ~ 11270000] INSERT 완료
# ✅ [11270000 ~ 11280000] INSERT 완료
# ✅ [11280000 ~ 11290000] INSERT 완료
# ✅ [11290000 ~ 11300000] INSERT 완료
# ✅ [11300000 ~ 11310000] INSERT 완료
# ✅ [11310000 ~ 11320000] INSERT 완료
# ✅ [11320000 ~ 11330000] INSERT 완료
# ✅ [11330000 ~ 11340000] INSERT 완료
# ✅ [11340000 ~ 11350000] INSERT 완료
# ✅ [11350000 ~ 11360000] INSERT 완료
# ✅ [11360000 ~ 11370000] INSERT 완료
# ✅ [11370000 ~ 11380000] INSERT 완료
# ✅ [11380000 ~ 11390000] INSERT 완료
# ✅ [11390000 ~ 11400000] INSERT 완료
# ✅ [11400000 ~ 11410000] INSERT 완료
# ✅ [11410000 ~ 11420000] INSERT 완료
# ✅ [11420000 ~ 11430000] INSERT 완료
# ✅ [11430000 ~ 11440000] INSERT 완료
# ✅ [11440000 ~ 11450000] INSERT 완료
# ✅ [11450000 ~ 11460000] INSERT 완료
# ✅ [11460000 ~ 11470000] INSERT 완료
# ✅ [11470000 ~ 11480000] INSERT 완료
# ✅ [11480000 ~ 11490000] INSERT 완료
# ✅ [11490000 ~ 11500000] INSERT 완료
# ✅ [11500000 ~ 11510000] INSERT 완료
# ✅ [11510000 ~ 11520000] INSERT 완료
# ✅ [11520000 ~ 11530000] INSERT 완료
# ✅ [11530000 ~ 11540000] INSERT 완료
# ✅ [11540000 ~ 11550000] INSERT 완료
# ✅ [11550000 ~ 11560000] INSERT 완료
# ✅ [11560000 ~ 11570000] INSERT 완료
# ✅ [11570000 ~ 11580000] INSERT 완료
# ✅ [11580000 ~ 11590000] INSERT 완료
# ✅ [11590000 ~ 11600000] INSERT 완료
# ✅ [11600000 ~ 11610000] INSERT 완료
# ✅ [11610000 ~ 11620000] INSERT 완료
# ✅ [11620000 ~ 11630000] INSERT 완료
# ✅ [11630000 ~ 11640000] INSERT 완료
# ✅ [11640000 ~ 11650000] INSERT 완료
# ✅ [11650000 ~ 11660000] INSERT 완료
# ✅ [11660000 ~ 11670000] INSERT 완료
# ✅ [11670000 ~ 11680000] INSERT 완료
# ✅ [11680000 ~ 11690000] INSERT 완료
# ✅ [11690000 ~ 11700000] INSERT 완료
# ✅ [11700000 ~ 11710000] INSERT 완료
# ✅ [11710000 ~ 11720000] INSERT 완료
# ✅ [11720000 ~ 11730000] INSERT 완료
# ✅ [11730000 ~ 11740000] INSERT 완료
# ✅ [11740000 ~ 11750000] INSERT 완료
# ✅ [11750000 ~ 11760000] INSERT 완료
# ✅ [11760000 ~ 11770000] INSERT 완료
# ✅ [11770000 ~ 11780000] INSERT 완료
# ✅ [11780000 ~ 11790000] INSERT 완료
# ✅ [11790000 ~ 11800000] INSERT 완료
# ✅ [11800000 ~ 11810000] INSERT 완료
# ✅ [11810000 ~ 11820000] INSERT 완료
# ✅ [11820000 ~ 11830000] INSERT 완료
# ✅ [11830000 ~ 11840000] INSERT 완료
# ✅ [11840000 ~ 11850000] INSERT 완료
# ✅ [11850000 ~ 11860000] INSERT 완료
# ✅ [11860000 ~ 11870000] INSERT 완료
# ✅ [11870000 ~ 11880000] INSERT 완료
# ✅ [11880000 ~ 11890000] INSERT 완료
# ✅ [11890000 ~ 11900000] INSERT 완료
# ✅ [11900000 ~ 11910000] INSERT 완료
# ✅ [11910000 ~ 11920000] INSERT 완료
# ✅ [11920000 ~ 11930000] INSERT 완료
# ✅ [11930000 ~ 11940000] INSERT 완료
# ✅ [11940000 ~ 11950000] INSERT 완료
# ✅ [11950000 ~ 11960000] INSERT 완료
# ✅ [11960000 ~ 11970000] INSERT 완료
# ✅ [11970000 ~ 11980000] INSERT 완료
# ✅ [11980000 ~ 11990000] INSERT 완료
# ✅ [11990000 ~ 12000000] INSERT 완료
# ✅ [12000000 ~ 12010000] INSERT 완료
# ✅ [12010000 ~ 12020000] INSERT 완료
# ✅ [12020000 ~ 12030000] INSERT 완료
# ✅ [12030000 ~ 12040000] INSERT 완료
# ✅ [12040000 ~ 12050000] INSERT 완료
# ✅ [12050000 ~ 12060000] INSERT 완료
# ✅ [12060000 ~ 12070000] INSERT 완료
# ✅ [12070000 ~ 12080000] INSERT 완료
# ✅ [12080000 ~ 12090000] INSERT 완료
# ✅ [12090000 ~ 12100000] INSERT 완료
# ✅ [12100000 ~ 12110000] INSERT 완료
# ✅ [12110000 ~ 12120000] INSERT 완료
# ✅ [12120000 ~ 12130000] INSERT 완료
# ✅ [12130000 ~ 12140000] INSERT 완료
# ✅ [12140000 ~ 12150000] INSERT 완료
# ✅ [12150000 ~ 12160000] INSERT 완료
# ✅ [12160000 ~ 12170000] INSERT 완료
# ✅ [12170000 ~ 12180000] INSERT 완료
# ✅ [12180000 ~ 12190000] INSERT 완료
# ✅ [12190000 ~ 12200000] INSERT 완료
# ✅ [12200000 ~ 12210000] INSERT 완료
# ✅ [12210000 ~ 12220000] INSERT 완료
# ✅ [12220000 ~ 12230000] INSERT 완료
# ✅ [12230000 ~ 12240000] INSERT 완료
# ✅ [12240000 ~ 12250000] INSERT 완료
# ✅ [12250000 ~ 12260000] INSERT 완료
# ✅ [12260000 ~ 12270000] INSERT 완료
# ✅ [12270000 ~ 12280000] INSERT 완료
# ✅ [12280000 ~ 12290000] INSERT 완료
# ✅ [12290000 ~ 12300000] INSERT 완료
# ✅ [12300000 ~ 12310000] INSERT 완료
# ✅ [12310000 ~ 12320000] INSERT 완료
# ✅ [12320000 ~ 12330000] INSERT 완료
# ✅ [12330000 ~ 12340000] INSERT 완료
# ✅ [12340000 ~ 12350000] INSERT 완료
# ✅ [12350000 ~ 12360000] INSERT 완료
# ✅ [12360000 ~ 12370000] INSERT 완료
# ✅ [12370000 ~ 12380000] INSERT 완료
# ✅ [12380000 ~ 12390000] INSERT 완료
# ✅ [12390000 ~ 12400000] INSERT 완료
# ✅ [12400000 ~ 12410000] INSERT 완료
# ✅ [12410000 ~ 12420000] INSERT 완료
# ✅ [12420000 ~ 12430000] INSERT 완료
# ✅ [12430000 ~ 12440000] INSERT 완료
# ✅ [12440000 ~ 12450000] INSERT 완료
# ✅ [12450000 ~ 12460000] INSERT 완료
# ✅ [12460000 ~ 12470000] INSERT 완료
# ✅ [12470000 ~ 12480000] INSERT 완료
# ✅ [12480000 ~ 12490000] INSERT 완료
# ✅ [12490000 ~ 12500000] INSERT 완료
# ✅ [12500000 ~ 12510000] INSERT 완료
# ✅ [12510000 ~ 12520000] INSERT 완료
# ✅ [12520000 ~ 12530000] INSERT 완료
# ✅ [12530000 ~ 12540000] INSERT 완료
# ✅ [12540000 ~ 12550000] INSERT 완료
# ✅ [12550000 ~ 12560000] INSERT 완료
# ✅ [12560000 ~ 12570000] INSERT 완료
# ✅ [12570000 ~ 12580000] INSERT 완료
# ✅ [12580000 ~ 12590000] INSERT 완료
# ✅ [12590000 ~ 12600000] INSERT 완료
# ✅ [12600000 ~ 12610000] INSERT 완료
# ✅ [12610000 ~ 12620000] INSERT 완료
# ✅ [12620000 ~ 12630000] INSERT 완료
# ✅ [12630000 ~ 12640000] INSERT 완료
# ✅ [12640000 ~ 12650000] INSERT 완료
# ✅ [12650000 ~ 12660000] INSERT 완료
# ✅ [12660000 ~ 12670000] INSERT 완료
# ✅ [12670000 ~ 12680000] INSERT 완료
# ✅ [12680000 ~ 12690000] INSERT 완료
# ✅ [12690000 ~ 12700000] INSERT 완료
# ✅ [12700000 ~ 12710000] INSERT 완료
# ✅ [12710000 ~ 12720000] INSERT 완료
# ✅ [12720000 ~ 12730000] INSERT 완료
# ✅ [12730000 ~ 12740000] INSERT 완료
# ✅ [12740000 ~ 12750000] INSERT 완료
# ✅ [12750000 ~ 12760000] INSERT 완료
# ✅ [12760000 ~ 12770000] INSERT 완료
# ✅ [12770000 ~ 12780000] INSERT 완료
# ✅ [12780000 ~ 12790000] INSERT 완료
# ✅ [12790000 ~ 12800000] INSERT 완료
# ✅ [12800000 ~ 12810000] INSERT 완료
# ✅ [12810000 ~ 12820000] INSERT 완료
# ✅ [12820000 ~ 12830000] INSERT 완료
# ✅ [12830000 ~ 12840000] INSERT 완료
# ✅ [12840000 ~ 12850000] INSERT 완료
# ✅ [12850000 ~ 12860000] INSERT 완료
# ✅ [12860000 ~ 12870000] INSERT 완료
# ✅ [12870000 ~ 12880000] INSERT 완료
# ✅ [12880000 ~ 12890000] INSERT 완료
# ✅ [12890000 ~ 12900000] INSERT 완료
# ✅ [12900000 ~ 12910000] INSERT 완료
# ✅ [12910000 ~ 12920000] INSERT 완료
# ✅ [12920000 ~ 12930000] INSERT 완료
# ✅ [12930000 ~ 12940000] INSERT 완료
# ✅ [12940000 ~ 12950000] INSERT 완료
# ✅ [12950000 ~ 12960000] INSERT 완료
# ✅ [12960000 ~ 12970000] INSERT 완료
# ✅ [12970000 ~ 12980000] INSERT 완료
# ✅ [12980000 ~ 12990000] INSERT 완료
# ✅ [12990000 ~ 13000000] INSERT 완료
# ✅ [13000000 ~ 13010000] INSERT 완료
# ✅ [13010000 ~ 13020000] INSERT 완료
# ✅ [13020000 ~ 13030000] INSERT 완료
# ✅ [13030000 ~ 13040000] INSERT 완료
# ✅ [13040000 ~ 13050000] INSERT 완료
# ✅ [13050000 ~ 13060000] INSERT 완료
# ✅ [13060000 ~ 13070000] INSERT 완료
# ✅ [13070000 ~ 13080000] INSERT 완료
# ✅ [13080000 ~ 13090000] INSERT 완료
# ✅ [13090000 ~ 13100000] INSERT 완료
# ✅ [13100000 ~ 13110000] INSERT 완료
# ✅ [13110000 ~ 13120000] INSERT 완료
# ✅ [13120000 ~ 13130000] INSERT 완료
# ✅ [13130000 ~ 13140000] INSERT 완료
# ✅ [13140000 ~ 13150000] INSERT 완료
# ✅ [13150000 ~ 13160000] INSERT 완료
# ✅ [13160000 ~ 13170000] INSERT 완료
# ✅ [13170000 ~ 13180000] INSERT 완료
# ✅ [13180000 ~ 13190000] INSERT 완료
# ✅ [13190000 ~ 13200000] INSERT 완료
# ✅ [13200000 ~ 13210000] INSERT 완료
# ✅ [13210000 ~ 13220000] INSERT 완료
# ✅ [13220000 ~ 13230000] INSERT 완료
# ✅ [13230000 ~ 13240000] INSERT 완료
# ✅ [13240000 ~ 13250000] INSERT 완료
# ✅ [13250000 ~ 13260000] INSERT 완료
# ✅ [13260000 ~ 13270000] INSERT 완료
# ✅ [13270000 ~ 13280000] INSERT 완료
# ✅ [13280000 ~ 13290000] INSERT 완료
# ✅ [13290000 ~ 13300000] INSERT 완료
# ✅ [13300000 ~ 13310000] INSERT 완료
# ✅ [13310000 ~ 13320000] INSERT 완료
# ✅ [13320000 ~ 13330000] INSERT 완료
# ✅ [13330000 ~ 13340000] INSERT 완료
# ✅ [13340000 ~ 13350000] INSERT 완료
# ✅ [13350000 ~ 13360000] INSERT 완료
# ✅ [13360000 ~ 13370000] INSERT 완료
# ✅ [13370000 ~ 13380000] INSERT 완료
# ✅ [13380000 ~ 13390000] INSERT 완료
# ✅ [13390000 ~ 13400000] INSERT 완료
# ✅ [13400000 ~ 13410000] INSERT 완료
# ✅ [13410000 ~ 13420000] INSERT 완료
# ✅ [13420000 ~ 13430000] INSERT 완료
# ✅ [13430000 ~ 13440000] INSERT 완료
# ✅ [13440000 ~ 13450000] INSERT 완료
# ✅ [13450000 ~ 13460000] INSERT 완료
# ✅ [13460000 ~ 13470000] INSERT 완료
# ✅ [13470000 ~ 13480000] INSERT 완료
# ✅ [13480000 ~ 13490000] INSERT 완료
# ✅ [13490000 ~ 13500000] INSERT 완료
# ✅ [13500000 ~ 13510000] INSERT 완료
# ✅ [13510000 ~ 13520000] INSERT 완료
# ✅ [13520000 ~ 13530000] INSERT 완료
# ✅ [13530000 ~ 13540000] INSERT 완료
# ✅ [13540000 ~ 13550000] INSERT 완료
# ✅ [13550000 ~ 13560000] INSERT 완료
# ✅ [13560000 ~ 13570000] INSERT 완료
# ✅ [13570000 ~ 13580000] INSERT 완료
# ✅ [13580000 ~ 13590000] INSERT 완료
# ✅ [13590000 ~ 13600000] INSERT 완료
# ✅ [13600000 ~ 13610000] INSERT 완료
# ✅ [13610000 ~ 13620000] INSERT 완료
# ✅ [13620000 ~ 13630000] INSERT 완료
# ✅ [13630000 ~ 13640000] INSERT 완료
# ✅ [13640000 ~ 13650000] INSERT 완료
# ✅ [13650000 ~ 13660000] INSERT 완료
# ✅ [13660000 ~ 13670000] INSERT 완료
# ✅ [13670000 ~ 13680000] INSERT 완료
# ✅ [13680000 ~ 13690000] INSERT 완료
# ✅ [13690000 ~ 13700000] INSERT 완료
# ✅ [13700000 ~ 13710000] INSERT 완료
# ✅ [13710000 ~ 13720000] INSERT 완료
# ✅ [13720000 ~ 13730000] INSERT 완료
# ✅ [13730000 ~ 13740000] INSERT 완료
# ✅ [13740000 ~ 13750000] INSERT 완료
# ✅ [13750000 ~ 13760000] INSERT 완료
# ✅ [13760000 ~ 13770000] INSERT 완료
# ✅ [13770000 ~ 13780000] INSERT 완료
# ✅ [13780000 ~ 13790000] INSERT 완료
# ✅ [13790000 ~ 13800000] INSERT 완료
# ✅ [13800000 ~ 13810000] INSERT 완료
# ✅ [13810000 ~ 13820000] INSERT 완료
# ✅ [13820000 ~ 13830000] INSERT 완료
# ✅ [13830000 ~ 13840000] INSERT 완료
# ✅ [13840000 ~ 13850000] INSERT 완료
# ✅ [13850000 ~ 13860000] INSERT 완료
# ✅ [13860000 ~ 13870000] INSERT 완료
# ✅ [13870000 ~ 13880000] INSERT 완료
# ✅ [13880000 ~ 13890000] INSERT 완료
# ✅ [13890000 ~ 13900000] INSERT 완료
# ✅ [13900000 ~ 13910000] INSERT 완료
# ✅ [13910000 ~ 13920000] INSERT 완료
# ✅ [13920000 ~ 13930000] INSERT 완료
# ✅ [13930000 ~ 13940000] INSERT 완료
# ✅ [13940000 ~ 13950000] INSERT 완료
# ✅ [13950000 ~ 13960000] INSERT 완료
# ✅ [13960000 ~ 13970000] INSERT 완료
# ✅ [13970000 ~ 13980000] INSERT 완료
# ✅ [13980000 ~ 13990000] INSERT 완료
# ✅ [13990000 ~ 14000000] INSERT 완료
# ✅ [14000000 ~ 14010000] INSERT 완료
# ✅ [14010000 ~ 14020000] INSERT 완료
# ✅ [14020000 ~ 14030000] INSERT 완료
# ✅ [14030000 ~ 14040000] INSERT 완료
# ✅ [14040000 ~ 14050000] INSERT 완료
# ✅ [14050000 ~ 14060000] INSERT 완료
# ✅ [14060000 ~ 14070000] INSERT 완료
# ✅ [14070000 ~ 14080000] INSERT 완료
# ✅ [14080000 ~ 14090000] INSERT 완료
# ✅ [14090000 ~ 14100000] INSERT 완료
# ✅ [14100000 ~ 14110000] INSERT 완료
# ✅ [14110000 ~ 14120000] INSERT 완료
# ✅ [14120000 ~ 14130000] INSERT 완료
# ✅ [14130000 ~ 14140000] INSERT 완료
# ✅ [14140000 ~ 14150000] INSERT 완료
# ✅ [14150000 ~ 14160000] INSERT 완료
# ✅ [14160000 ~ 14170000] INSERT 완료
# ✅ [14170000 ~ 14180000] INSERT 완료
# ✅ [14180000 ~ 14190000] INSERT 완료
# ✅ [14190000 ~ 14200000] INSERT 완료
# ✅ [14200000 ~ 14210000] INSERT 완료
# ✅ [14210000 ~ 14220000] INSERT 완료
# ✅ [14220000 ~ 14230000] INSERT 완료
# ✅ [14230000 ~ 14240000] INSERT 완료
# ✅ [14240000 ~ 14250000] INSERT 완료
# ✅ [14250000 ~ 14260000] INSERT 완료
# ✅ [14260000 ~ 14270000] INSERT 완료
# ✅ [14270000 ~ 14280000] INSERT 완료
# ✅ [14280000 ~ 14290000] INSERT 완료
# ✅ [14290000 ~ 14300000] INSERT 완료
# ✅ [14300000 ~ 14310000] INSERT 완료
# ✅ [14310000 ~ 14320000] INSERT 완료
# ✅ [14320000 ~ 14330000] INSERT 완료
# ✅ [14330000 ~ 14340000] INSERT 완료
# ✅ [14340000 ~ 14350000] INSERT 완료
# ✅ [14350000 ~ 14360000] INSERT 완료
# ✅ [14360000 ~ 14370000] INSERT 완료
# ✅ [14370000 ~ 14380000] INSERT 완료
# ✅ [14380000 ~ 14390000] INSERT 완료
# ✅ [14390000 ~ 14400000] INSERT 완료
# ✅ [14400000 ~ 14410000] INSERT 완료
# ✅ [14410000 ~ 14420000] INSERT 완료
# ✅ [14420000 ~ 14430000] INSERT 완료
# ✅ [14430000 ~ 14440000] INSERT 완료
# ✅ [14440000 ~ 14450000] INSERT 완료
# ✅ [14450000 ~ 14460000] INSERT 완료
# ✅ [14460000 ~ 14470000] INSERT 완료
# ✅ [14470000 ~ 14480000] INSERT 완료
# ✅ [14480000 ~ 14490000] INSERT 완료
# ✅ [14490000 ~ 14500000] INSERT 완료
# ✅ [14500000 ~ 14510000] INSERT 완료
# ✅ [14510000 ~ 14520000] INSERT 완료
# ✅ [14520000 ~ 14530000] INSERT 완료
# ✅ [14530000 ~ 14540000] INSERT 완료
# ✅ [14540000 ~ 14550000] INSERT 완료
# ✅ [14550000 ~ 14560000] INSERT 완료
# ✅ [14560000 ~ 14570000] INSERT 완료
# ✅ [14570000 ~ 14580000] INSERT 완료
# ✅ [14580000 ~ 14590000] INSERT 완료
# ✅ [14590000 ~ 14600000] INSERT 완료
# ✅ [14600000 ~ 14610000] INSERT 완료
# ✅ [14610000 ~ 14620000] INSERT 완료
# ✅ [14620000 ~ 14630000] INSERT 완료
# ✅ [14630000 ~ 14640000] INSERT 완료
# ✅ [14640000 ~ 14650000] INSERT 완료
# ✅ [14650000 ~ 14660000] INSERT 완료
# ✅ [14660000 ~ 14670000] INSERT 완료
# ✅ [14670000 ~ 14680000] INSERT 완료
# ✅ [14680000 ~ 14690000] INSERT 완료
# ✅ [14690000 ~ 14700000] INSERT 완료
# ✅ [14700000 ~ 14710000] INSERT 완료
# ✅ [14710000 ~ 14720000] INSERT 완료
# ✅ [14720000 ~ 14730000] INSERT 완료
# ✅ [14730000 ~ 14740000] INSERT 완료
# ✅ [14740000 ~ 14750000] INSERT 완료
# ✅ [14750000 ~ 14760000] INSERT 완료
# ✅ [14760000 ~ 14770000] INSERT 완료
# ...
# ✅ [39850000 ~ 39860000] INSERT 완료
# ✅ [39860000 ~ 39870000] INSERT 완료
# ✅ [39870000 ~ 39880000] INSERT 완료
# ✅ [39880000 ~ 39890000] INSERT 완료
# ✅ [39890000 ~ 39900000] INSERT 완료
# ✅ [39900000 ~ 39910000] INSERT 완료
# ✅ [39910000 ~ 39920000] INSERT 완료
# ✅ [39920000 ~ 39930000] INSERT 완료
# ✅ [39930000 ~ 39940000] INSERT 완료
# ✅ [39940000 ~ 39950000] INSERT 완료
# ✅ [39950000 ~ 39960000] INSERT 완료
# ✅ [39960000 ~ 39970000] INSERT 완료
# ✅ [39970000 ~ 39980000] INSERT 완료
# ✅ [39980000 ~ 39990000] INSERT 완료
# ✅ [39990000 ~ 40000000] INSERT 완료
# ✅ [40000000 ~ 40010000] INSERT 완료
# ✅ [40010000 ~ 40020000] INSERT 완료
# ✅ [40020000 ~ 40030000] INSERT 완료
# ✅ [40030000 ~ 40040000] INSERT 완료
# ✅ [40040000 ~ 40050000] INSERT 완료
# ✅ [40050000 ~ 40060000] INSERT 완료
# ✅ [40060000 ~ 40070000] INSERT 완료
# ✅ [40070000 ~ 40080000] INSERT 완료
# ✅ [40080000 ~ 40090000] INSERT 완료
# ✅ [40090000 ~ 40100000] INSERT 완료
# ✅ [40100000 ~ 40110000] INSERT 완료
# ✅ [40110000 ~ 40120000] INSERT 완료
# ✅ [40120000 ~ 40130000] INSERT 완료
# ✅ [40130000 ~ 40140000] INSERT 완료
# ✅ [40140000 ~ 40150000] INSERT 완료
# ✅ [40150000 ~ 40160000] INSERT 완료
# ✅ [40160000 ~ 40170000] INSERT 완료
# ✅ [40170000 ~ 40180000] INSERT 완료
# ✅ [40180000 ~ 40190000] INSERT 완료
# ✅ [40190000 ~ 40200000] INSERT 완료
# ✅ [40200000 ~ 40210000] INSERT 완료
# ✅ [40210000 ~ 40220000] INSERT 완료
# ✅ [40220000 ~ 40230000] INSERT 완료
# ✅ [40230000 ~ 40240000] INSERT 완료
# ✅ [40240000 ~ 40250000] INSERT 완료
# ✅ [40250000 ~ 40260000] INSERT 완료
# ✅ [40260000 ~ 40270000] INSERT 완료
# ✅ [40270000 ~ 40280000] INSERT 완료
# ✅ [40280000 ~ 40290000] INSERT 완료
# ✅ [40290000 ~ 40300000] INSERT 완료
# ✅ [40300000 ~ 40310000] INSERT 완료
# ✅ [40310000 ~ 40320000] INSERT 완료
# ✅ [40320000 ~ 40330000] INSERT 완료
# ✅ [40330000 ~ 40340000] INSERT 완료
# ✅ [40340000 ~ 40350000] INSERT 완료
# ✅ [40350000 ~ 40360000] INSERT 완료
# ✅ [40360000 ~ 40370000] INSERT 완료
# ✅ [40370000 ~ 40380000] INSERT 완료
# ✅ [40380000 ~ 40390000] INSERT 완료
# ✅ [40390000 ~ 40400000] INSERT 완료
# ✅ [40400000 ~ 40410000] INSERT 완료
# ✅ [40410000 ~ 40420000] INSERT 완료
# ✅ [40420000 ~ 40430000] INSERT 완료
# ✅ [40430000 ~ 40440000] INSERT 완료
# ✅ [40440000 ~ 40450000] INSERT 완료
# ✅ [40450000 ~ 40460000] INSERT 완료
# ✅ [40460000 ~ 40470000] INSERT 완료
# ✅ [40470000 ~ 40480000] INSERT 완료
# ✅ [40480000 ~ 40490000] INSERT 완료
# ✅ [40490000 ~ 40500000] INSERT 완료
# ✅ [40500000 ~ 40510000] INSERT 완료
# ✅ [40510000 ~ 40520000] INSERT 완료
# ✅ [40520000 ~ 40530000] INSERT 완료
# ✅ [40530000 ~ 40540000] INSERT 완료
# ✅ [40540000 ~ 40550000] INSERT 완료
# ✅ [40550000 ~ 40560000] INSERT 완료
# ✅ [40560000 ~ 40570000] INSERT 완료
# ✅ [40570000 ~ 40580000] INSERT 완료
# ✅ [40580000 ~ 40590000] INSERT 완료
# ✅ [40590000 ~ 40600000] INSERT 완료
# ✅ [40600000 ~ 40610000] INSERT 완료
# ✅ [40610000 ~ 40620000] INSERT 완료
# ✅ [40620000 ~ 40630000] INSERT 완료
# ✅ [40630000 ~ 40640000] INSERT 완료
# ✅ [40640000 ~ 40650000] INSERT 완료
# ✅ [40650000 ~ 40660000] INSERT 완료
# ✅ [40660000 ~ 40670000] INSERT 완료
# ✅ [40670000 ~ 40680000] INSERT 완료
# ✅ [40680000 ~ 40690000] INSERT 완료
# ✅ [40690000 ~ 40700000] INSERT 완료
# ✅ [40700000 ~ 40710000] INSERT 완료
# ✅ [40710000 ~ 40720000] INSERT 완료
# ✅ [40720000 ~ 40730000] INSERT 완료
# ✅ [40730000 ~ 40740000] INSERT 완료
# ✅ [40740000 ~ 40750000] INSERT 완료
# ✅ [40750000 ~ 40760000] INSERT 완료
# ✅ [40760000 ~ 40770000] INSERT 완료
# ✅ [40770000 ~ 40780000] INSERT 완료
# ✅ [40780000 ~ 40790000] INSERT 완료
# ✅ [40790000 ~ 40800000] INSERT 완료
# ✅ [40800000 ~ 40810000] INSERT 완료
# ✅ [40810000 ~ 40820000] INSERT 완료
# ✅ [40820000 ~ 40830000] INSERT 완료
# ✅ [40830000 ~ 40840000] INSERT 완료
# ✅ [40840000 ~ 40850000] INSERT 완료
# ✅ [40850000 ~ 40860000] INSERT 완료
# ✅ [40860000 ~ 40870000] INSERT 완료
# ✅ [40870000 ~ 40880000] INSERT 완료
# ✅ [40880000 ~ 40890000] INSERT 완료
# ✅ [40890000 ~ 40900000] INSERT 완료
# ✅ [40900000 ~ 40910000] INSERT 완료
# ✅ [40910000 ~ 40920000] INSERT 완료
# ✅ [40920000 ~ 40930000] INSERT 완료
# ✅ [40930000 ~ 40940000] INSERT 완료
# ✅ [40940000 ~ 40950000] INSERT 완료
# ✅ [40950000 ~ 40960000] INSERT 완료
# ✅ [40960000 ~ 40970000] INSERT 완료
# ✅ [40970000 ~ 40980000] INSERT 완료
# ✅ [40980000 ~ 40990000] INSERT 완료
# ✅ [40990000 ~ 41000000] INSERT 완료
# ✅ [41000000 ~ 41010000] INSERT 완료
# ✅ [41010000 ~ 41020000] INSERT 완료
# ✅ [41020000 ~ 41030000] INSERT 완료
# ✅ [41030000 ~ 41040000] INSERT 완료
# ✅ [41040000 ~ 41050000] INSERT 완료
# ✅ [41050000 ~ 41060000] INSERT 완료
# ✅ [41060000 ~ 41070000] INSERT 완료
# ✅ [41070000 ~ 41080000] INSERT 완료
# ✅ [41080000 ~ 41090000] INSERT 완료
# ✅ [41090000 ~ 41100000] INSERT 완료
# ✅ [41100000 ~ 41110000] INSERT 완료
# ✅ [41110000 ~ 41120000] INSERT 완료
# ✅ [41120000 ~ 41130000] INSERT 완료
# ✅ [41130000 ~ 41140000] INSERT 완료
# ✅ [41140000 ~ 41150000] INSERT 완료
# ✅ [41150000 ~ 41160000] INSERT 완료
# ✅ [41160000 ~ 41170000] INSERT 완료
# ✅ [41170000 ~ 41180000] INSERT 완료
# ✅ [41180000 ~ 41190000] INSERT 완료
# ✅ [41190000 ~ 41200000] INSERT 완료
# ✅ [41200000 ~ 41210000] INSERT 완료
# ✅ [41210000 ~ 41220000] INSERT 완료
# ✅ [41220000 ~ 41230000] INSERT 완료
# ✅ [41230000 ~ 41240000] INSERT 완료
# ✅ [41240000 ~ 41250000] INSERT 완료
# ✅ [41250000 ~ 41260000] INSERT 완료
# ✅ [41260000 ~ 41270000] INSERT 완료
# ✅ [41270000 ~ 41280000] INSERT 완료
# ✅ [41280000 ~ 41290000] INSERT 완료
# ✅ [41290000 ~ 41300000] INSERT 완료
# ✅ [41300000 ~ 41310000] INSERT 완료
# ✅ [41310000 ~ 41320000] INSERT 완료
# ✅ [41320000 ~ 41330000] INSERT 완료
# ✅ [41330000 ~ 41340000] INSERT 완료
# ✅ [41340000 ~ 41350000] INSERT 완료
# ✅ [41350000 ~ 41360000] INSERT 완료
# ✅ [41360000 ~ 41370000] INSERT 완료
# ✅ [41370000 ~ 41380000] INSERT 완료
# ✅ [41380000 ~ 41390000] INSERT 완료
# ✅ [41390000 ~ 41400000] INSERT 완료
# ✅ [41400000 ~ 41410000] INSERT 완료
# ✅ [41410000 ~ 41420000] INSERT 완료
# ✅ [41420000 ~ 41430000] INSERT 완료
# ✅ [41430000 ~ 41440000] INSERT 완료
# ✅ [41440000 ~ 41450000] INSERT 완료
# ✅ [41450000 ~ 41460000] INSERT 완료
# ✅ [41460000 ~ 41470000] INSERT 완료
# ✅ [41470000 ~ 41480000] INSERT 완료
# ✅ [41480000 ~ 41490000] INSERT 완료
# ✅ [41490000 ~ 41500000] INSERT 완료
# ✅ [41500000 ~ 41510000] INSERT 완료
# ✅ [41510000 ~ 41520000] INSERT 완료
# ✅ [41520000 ~ 41530000] INSERT 완료
# ✅ [41530000 ~ 41540000] INSERT 완료
# ✅ [41540000 ~ 41550000] INSERT 완료
# ✅ [41550000 ~ 41560000] INSERT 완료
# ✅ [41560000 ~ 41570000] INSERT 완료
# ✅ [41570000 ~ 41580000] INSERT 완료
# ✅ [41580000 ~ 41590000] INSERT 완료
# ✅ [41590000 ~ 41600000] INSERT 완료
# ✅ [41600000 ~ 41610000] INSERT 완료
# ✅ [41610000 ~ 41620000] INSERT 완료
# ✅ [41620000 ~ 41630000] INSERT 완료
# ✅ [41630000 ~ 41640000] INSERT 완료
# ✅ [41640000 ~ 41650000] INSERT 완료
# ✅ [41650000 ~ 41660000] INSERT 완료
# ✅ [41660000 ~ 41670000] INSERT 완료
# ✅ [41670000 ~ 41680000] INSERT 완료
# ✅ [41680000 ~ 41690000] INSERT 완료
# ✅ [41690000 ~ 41700000] INSERT 완료
# ✅ [41700000 ~ 41710000] INSERT 완료
# ✅ [41710000 ~ 41720000] INSERT 완료
# ✅ [41720000 ~ 41730000] INSERT 완료
# ✅ [41730000 ~ 41740000] INSERT 완료
# ✅ [41740000 ~ 41750000] INSERT 완료
# ✅ [41750000 ~ 41760000] INSERT 완료
# ✅ [41760000 ~ 41770000] INSERT 완료
# ✅ [41770000 ~ 41780000] INSERT 완료
# ✅ [41780000 ~ 41790000] INSERT 완료
# ✅ [41790000 ~ 41800000] INSERT 완료
# ✅ [41800000 ~ 41810000] INSERT 완료
# ✅ [41810000 ~ 41820000] INSERT 완료
# ✅ [41820000 ~ 41830000] INSERT 완료
# ✅ [41830000 ~ 41840000] INSERT 완료
# ✅ [41840000 ~ 41850000] INSERT 완료
# ✅ [41850000 ~ 41860000] INSERT 완료
# ✅ [41860000 ~ 41870000] INSERT 완료
# ✅ [41870000 ~ 41880000] INSERT 완료
# ✅ [41880000 ~ 41890000] INSERT 완료
# ✅ [41890000 ~ 41900000] INSERT 완료
# ✅ [41900000 ~ 41910000] INSERT 완료
# ✅ [41910000 ~ 41920000] INSERT 완료
# ✅ [41920000 ~ 41930000] INSERT 완료
# ✅ [41930000 ~ 41940000] INSERT 완료
# ✅ [41940000 ~ 41950000] INSERT 완료
# ✅ [41950000 ~ 41960000] INSERT 완료
# ✅ [41960000 ~ 41970000] INSERT 완료
# ✅ [41970000 ~ 41980000] INSERT 완료
# ✅ [41980000 ~ 41990000] INSERT 완료
# ✅ [41990000 ~ 42000000] INSERT 완료
# ✅ [42000000 ~ 42010000] INSERT 완료
# ✅ [42010000 ~ 42020000] INSERT 완료
# ✅ [42020000 ~ 42030000] INSERT 완료
# ✅ [42030000 ~ 42040000] INSERT 완료
# ✅ [42040000 ~ 42050000] INSERT 완료
# ✅ [42050000 ~ 42060000] INSERT 완료
# ✅ [42060000 ~ 42070000] INSERT 완료
# ✅ [42070000 ~ 42080000] INSERT 완료
# ✅ [42080000 ~ 42090000] INSERT 완료
# ✅ [42090000 ~ 42100000] INSERT 완료
# ✅ [42100000 ~ 42110000] INSERT 완료
# ✅ [42110000 ~ 42120000] INSERT 완료
# ✅ [42120000 ~ 42130000] INSERT 완료
# ✅ [42130000 ~ 42140000] INSERT 완료
# ✅ [42140000 ~ 42150000] INSERT 완료
# ✅ [42150000 ~ 42160000] INSERT 완료
# ✅ [42160000 ~ 42170000] INSERT 완료
# ✅ [42170000 ~ 42180000] INSERT 완료
# ✅ [42180000 ~ 42190000] INSERT 완료
# ✅ [42190000 ~ 42200000] INSERT 완료
# ✅ [42200000 ~ 42210000] INSERT 완료
# ✅ [42210000 ~ 42220000] INSERT 완료
# ✅ [42220000 ~ 42230000] INSERT 완료
# ✅ [42230000 ~ 42240000] INSERT 완료
# ✅ [42240000 ~ 42250000] INSERT 완료
# ✅ [42250000 ~ 42260000] INSERT 완료
# ✅ [42260000 ~ 42270000] INSERT 완료
# ✅ [42270000 ~ 42280000] INSERT 완료
# ✅ [42280000 ~ 42290000] INSERT 완료
# ✅ [42290000 ~ 42300000] INSERT 완료
# ✅ [42300000 ~ 42310000] INSERT 완료
# ✅ [42310000 ~ 42320000] INSERT 완료
# ✅ [42320000 ~ 42330000] INSERT 완료
# ✅ [42330000 ~ 42340000] INSERT 완료
# ✅ [42340000 ~ 42350000] INSERT 완료
# ✅ [42350000 ~ 42360000] INSERT 완료
# ✅ [42360000 ~ 42370000] INSERT 완료
# ✅ [42370000 ~ 42380000] INSERT 완료
# ✅ [42380000 ~ 42390000] INSERT 완료
# ✅ [42390000 ~ 42400000] INSERT 완료
# ✅ [42400000 ~ 42410000] INSERT 완료
# ✅ [42410000 ~ 42420000] INSERT 완료
# ✅ [42420000 ~ 42430000] INSERT 완료
# ✅ [42430000 ~ 42440000] INSERT 완료
# ✅ [42440000 ~ 42450000] INSERT 완료
# ✅ [42450000 ~ 42460000] INSERT 완료
# ✅ [42460000 ~ 42470000] INSERT 완료
# ✅ [42470000 ~ 42480000] INSERT 완료
# ✅ [42480000 ~ 42490000] INSERT 완료
# ✅ [42490000 ~ 42500000] INSERT 완료
# ✅ [42500000 ~ 42510000] INSERT 완료
# ✅ [42510000 ~ 42520000] INSERT 완료
# ✅ [42520000 ~ 42530000] INSERT 완료
# ✅ [42530000 ~ 42540000] INSERT 완료
# ✅ [42540000 ~ 42550000] INSERT 완료
# ✅ [42550000 ~ 42560000] INSERT 완료
# ✅ [42560000 ~ 42570000] INSERT 완료
# ✅ [42570000 ~ 42580000] INSERT 완료
# ✅ [42580000 ~ 42590000] INSERT 완료
# ✅ [42590000 ~ 42600000] INSERT 완료
# ✅ [42600000 ~ 42610000] INSERT 완료
# ✅ [42610000 ~ 42620000] INSERT 완료
# ✅ [42620000 ~ 42630000] INSERT 완료
# ✅ [42630000 ~ 42640000] INSERT 완료
# ✅ [42640000 ~ 42650000] INSERT 완료
# ✅ [42650000 ~ 42660000] INSERT 완료
# ✅ [42660000 ~ 42670000] INSERT 완료
# ✅ [42670000 ~ 42680000] INSERT 완료
# ✅ [42680000 ~ 42690000] INSERT 완료
# ✅ [42690000 ~ 42700000] INSERT 완료
# ✅ [42700000 ~ 42710000] INSERT 완료
# ✅ [42710000 ~ 42720000] INSERT 완료
# ✅ [42720000 ~ 42730000] INSERT 완료
# ✅ [42730000 ~ 42740000] INSERT 완료
# ✅ [42740000 ~ 42750000] INSERT 완료
# ✅ [42750000 ~ 42760000] INSERT 완료
# ✅ [42760000 ~ 42770000] INSERT 완료
# ✅ [42770000 ~ 42780000] INSERT 완료
# ✅ [42780000 ~ 42790000] INSERT 완료
# ✅ [42790000 ~ 42800000] INSERT 완료
# ✅ [42800000 ~ 42810000] INSERT 완료
# ✅ [42810000 ~ 42820000] INSERT 완료
# ✅ [42820000 ~ 42830000] INSERT 완료
# ✅ [42830000 ~ 42840000] INSERT 완료
# ✅ [42840000 ~ 42850000] INSERT 완료
# ✅ [42850000 ~ 42860000] INSERT 완료
# ✅ [42860000 ~ 42870000] INSERT 완료
# ✅ [42870000 ~ 42880000] INSERT 완료
# ✅ [42880000 ~ 42890000] INSERT 완료
# ✅ [42890000 ~ 42900000] INSERT 완료
# ✅ [42900000 ~ 42910000] INSERT 완료
# ✅ [42910000 ~ 42920000] INSERT 완료
# ✅ [42920000 ~ 42930000] INSERT 완료
# ✅ [42930000 ~ 42940000] INSERT 완료
# ✅ [42940000 ~ 42950000] INSERT 완료
# ✅ [42950000 ~ 42960000] INSERT 완료
# ✅ [42960000 ~ 42970000] INSERT 완료
# ✅ [42970000 ~ 42980000] INSERT 완료
# ✅ [42980000 ~ 42990000] INSERT 완료
# ✅ [42990000 ~ 43000000] INSERT 완료
# ✅ [43000000 ~ 43010000] INSERT 완료
# ✅ [43010000 ~ 43020000] INSERT 완료
# ✅ [43020000 ~ 43030000] INSERT 완료
# ✅ [43030000 ~ 43040000] INSERT 완료
# ✅ [43040000 ~ 43050000] INSERT 완료
# ✅ [43050000 ~ 43060000] INSERT 완료
# ✅ [43060000 ~ 43070000] INSERT 완료
# ✅ [43070000 ~ 43080000] INSERT 완료
# ✅ [43080000 ~ 43090000] INSERT 완료
# ✅ [43090000 ~ 43100000] INSERT 완료
# ✅ [43100000 ~ 43110000] INSERT 완료
# ✅ [43110000 ~ 43120000] INSERT 완료
# ✅ [43120000 ~ 43130000] INSERT 완료
# ✅ [43130000 ~ 43140000] INSERT 완료
# ✅ [43140000 ~ 43150000] INSERT 완료
# ✅ [43150000 ~ 43160000] INSERT 완료
# ✅ [43160000 ~ 43170000] INSERT 완료
# ✅ [43170000 ~ 43180000] INSERT 완료
# ✅ [43180000 ~ 43190000] INSERT 완료
# ✅ [43190000 ~ 43200000] INSERT 완료
# ✅ [43200000 ~ 43210000] INSERT 완료
# ✅ [43210000 ~ 43220000] INSERT 완료
# ✅ [43220000 ~ 43230000] INSERT 완료
# ✅ [43230000 ~ 43240000] INSERT 완료
# ✅ [43240000 ~ 43250000] INSERT 완료
# ✅ [43250000 ~ 43260000] INSERT 완료
# ✅ [43260000 ~ 43270000] INSERT 완료
# ✅ [43270000 ~ 43280000] INSERT 완료
# ✅ [43280000 ~ 43290000] INSERT 완료
# ✅ [43290000 ~ 43300000] INSERT 완료
# ✅ [43300000 ~ 43310000] INSERT 완료
# ✅ [43310000 ~ 43320000] INSERT 완료
# ✅ [43320000 ~ 43330000] INSERT 완료
# ✅ [43330000 ~ 43340000] INSERT 완료
# ✅ [43340000 ~ 43350000] INSERT 완료
# ✅ [43350000 ~ 43360000] INSERT 완료
# ✅ [43360000 ~ 43370000] INSERT 완료
# ✅ [43370000 ~ 43380000] INSERT 완료
# ✅ [43380000 ~ 43390000] INSERT 완료
# ✅ [43390000 ~ 43400000] INSERT 완료
# ✅ [43400000 ~ 43410000] INSERT 완료
# ✅ [43410000 ~ 43420000] INSERT 완료
# ✅ [43420000 ~ 43430000] INSERT 완료
# ✅ [43430000 ~ 43440000] INSERT 완료
# ✅ [43440000 ~ 43450000] INSERT 완료
# ✅ [43450000 ~ 43460000] INSERT 완료
# ✅ [43460000 ~ 43470000] INSERT 완료
# ✅ [43470000 ~ 43480000] INSERT 완료
# ✅ [43480000 ~ 43490000] INSERT 완료
# ✅ [43490000 ~ 43500000] INSERT 완료
# ✅ [43500000 ~ 43510000] INSERT 완료
# ✅ [43510000 ~ 43520000] INSERT 완료
# ✅ [43520000 ~ 43530000] INSERT 완료
# ✅ [43530000 ~ 43540000] INSERT 완료
# ✅ [43540000 ~ 43550000] INSERT 완료
# ✅ [43550000 ~ 43560000] INSERT 완료
# ✅ [43560000 ~ 43570000] INSERT 완료
# ✅ [43570000 ~ 43580000] INSERT 완료
# ✅ [43580000 ~ 43590000] INSERT 완료
# ✅ [43590000 ~ 43600000] INSERT 완료
# ✅ [43600000 ~ 43610000] INSERT 완료
# ✅ [43610000 ~ 43620000] INSERT 완료
# ✅ [43620000 ~ 43630000] INSERT 완료
# ✅ [43630000 ~ 43640000] INSERT 완료
# ✅ [43640000 ~ 43650000] INSERT 완료
# ✅ [43650000 ~ 43660000] INSERT 완료
# ✅ [43660000 ~ 43670000] INSERT 완료
# ✅ [43670000 ~ 43680000] INSERT 완료
# ✅ [43680000 ~ 43690000] INSERT 완료
# ✅ [43690000 ~ 43700000] INSERT 완료
# ✅ [43700000 ~ 43710000] INSERT 완료
# ✅ [43710000 ~ 43720000] INSERT 완료
# ✅ [43720000 ~ 43730000] INSERT 완료
# ✅ [43730000 ~ 43740000] INSERT 완료
# ✅ [43740000 ~ 43750000] INSERT 완료
# ✅ [43750000 ~ 43760000] INSERT 완료
# ✅ [43760000 ~ 43770000] INSERT 완료
# ✅ [43770000 ~ 43780000] INSERT 완료
# ✅ [43780000 ~ 43790000] INSERT 완료
# ✅ [43790000 ~ 43800000] INSERT 완료
# ✅ [43800000 ~ 43810000] INSERT 완료
# ✅ [43810000 ~ 43820000] INSERT 완료
# ✅ [43820000 ~ 43830000] INSERT 완료
# ✅ [43830000 ~ 43840000] INSERT 완료
# ✅ [43840000 ~ 43850000] INSERT 완료
# ✅ [43850000 ~ 43860000] INSERT 완료
# ✅ [43860000 ~ 43870000] INSERT 완료
# ✅ [43870000 ~ 43880000] INSERT 완료
# ✅ [43880000 ~ 43890000] INSERT 완료
# ✅ [43890000 ~ 43900000] INSERT 완료
# ✅ [43900000 ~ 43910000] INSERT 완료
# ✅ [43910000 ~ 43920000] INSERT 완료
# ✅ [43920000 ~ 43930000] INSERT 완료
# ✅ [43930000 ~ 43940000] INSERT 완료
# ✅ [43940000 ~ 43950000] INSERT 완료
# ✅ [43950000 ~ 43960000] INSERT 완료
# ✅ [43960000 ~ 43970000] INSERT 완료
# ✅ [43970000 ~ 43980000] INSERT 완료
# ✅ [43980000 ~ 43990000] INSERT 완료
# ✅ [43990000 ~ 44000000] INSERT 완료
# ✅ [44000000 ~ 44010000] INSERT 완료
# ✅ [44010000 ~ 44020000] INSERT 완료
# ✅ [44020000 ~ 44030000] INSERT 완료
# ✅ [44030000 ~ 44040000] INSERT 완료
# ✅ [44040000 ~ 44050000] INSERT 완료
# ✅ [44050000 ~ 44060000] INSERT 완료
# ✅ [44060000 ~ 44070000] INSERT 완료
# ✅ [44070000 ~ 44080000] INSERT 완료
# ✅ [44080000 ~ 44090000] INSERT 완료
# ✅ [44090000 ~ 44100000] INSERT 완료
# ✅ [44100000 ~ 44110000] INSERT 완료
# ✅ [44110000 ~ 44120000] INSERT 완료
# ✅ [44120000 ~ 44130000] INSERT 완료
# ✅ [44130000 ~ 44140000] INSERT 완료
# ✅ [44140000 ~ 44150000] INSERT 완료
# ✅ [44150000 ~ 44160000] INSERT 완료
# ✅ [44160000 ~ 44170000] INSERT 완료
# ✅ [44170000 ~ 44180000] INSERT 완료
# ✅ [44180000 ~ 44190000] INSERT 완료
# ✅ [44190000 ~ 44200000] INSERT 완료
# ✅ [44200000 ~ 44210000] INSERT 완료
# ✅ [44210000 ~ 44220000] INSERT 완료
# ✅ [44220000 ~ 44230000] INSERT 완료
# ✅ [44230000 ~ 44240000] INSERT 완료
# ✅ [44240000 ~ 44250000] INSERT 완료
# ✅ [44250000 ~ 44260000] INSERT 완료
# ✅ [44260000 ~ 44270000] INSERT 완료
# ✅ [44270000 ~ 44280000] INSERT 완료
# ✅ [44280000 ~ 44290000] INSERT 완료
# ✅ [44290000 ~ 44300000] INSERT 완료
# ✅ [44300000 ~ 44310000] INSERT 완료
# ✅ [44310000 ~ 44320000] INSERT 완료
# ✅ [44320000 ~ 44330000] INSERT 완료
# ✅ [44330000 ~ 44340000] INSERT 완료
# ✅ [44340000 ~ 44350000] INSERT 완료
# ✅ [44350000 ~ 44360000] INSERT 완료
# ✅ [44360000 ~ 44370000] INSERT 완료
# ✅ [44370000 ~ 44380000] INSERT 완료
# ✅ [44380000 ~ 44390000] INSERT 완료
# ✅ [44390000 ~ 44400000] INSERT 완료
# ✅ [44400000 ~ 44410000] INSERT 완료
# ✅ [44410000 ~ 44420000] INSERT 완료
# ✅ [44420000 ~ 44430000] INSERT 완료
# ✅ [44430000 ~ 44440000] INSERT 완료
# ✅ [44440000 ~ 44450000] INSERT 완료
# ✅ [44450000 ~ 44460000] INSERT 완료
# ✅ [44460000 ~ 44470000] INSERT 완료
# ✅ [44470000 ~ 44480000] INSERT 완료
# ✅ [44480000 ~ 44490000] INSERT 완료
# ✅ [44490000 ~ 44500000] INSERT 완료
# ✅ [44500000 ~ 44510000] INSERT 완료
# ✅ [44510000 ~ 44520000] INSERT 완료
# ✅ [44520000 ~ 44530000] INSERT 완료
# ✅ [44530000 ~ 44540000] INSERT 완료
# ✅ [44540000 ~ 44543263] INSERT 완료
